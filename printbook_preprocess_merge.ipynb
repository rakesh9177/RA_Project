# %%
import pandas as pd

# %%
import pandas as pd

def get_printbook_sales_data():
    
    sales = pd.read_csv('sales/printbook_sales.csv')
    sales= sales[~sales['isbn13'].isna()]
    sales = sales[~sales['datepublished'].isna()]
    sales.reset_index(drop=True, inplace=True)
    sales['datepublished']  = pd.to_datetime(sales['datepublished'], errors = 'coerce')
    #sales.rename(columns={'datepublished' : 'datepublished_sales_data'})
    sales = sales[['totalunits', 'price', 'totalrevenue', 'isbn13', 'salesdate','datepublished']]
    
    #This is monthly revenue of books. Aggregating revenue by each book
    sales = sales.groupby(['isbn13','datepublished'], as_index=False).agg({'totalrevenue':'sum', 'totalunits':'sum', 'price':'mean'})
    
    return sales

def get_advances_data():
    
    adv = pd.read_excel('author_advance_dataset.xlsx', index_col=0)
    adv = adv[~adv['Advance'].isna()]
    deals = {
    'NICE' : (1+49000)/2,
    'VERY NICE' : (50000 + 99000)/2,
    'GOOD' : (100000 + 250000)/2,
    'SIGNIFICANT' : (251000 + 499000)/2,
    'MAJOR' : (500000 + 750000)/2
    }
    adv['Advance'] = adv['Advance'].replace(deals)
    return adv

def get_printbook_title_data():
    
    book = pd.read_csv('books/booktitle_printbooks_new.csv')
    book = book[['author','title','isbn13', 'datepublished']]
    book['datepublished']  = pd.to_datetime(book['datepublished'], errors = 'coerce')
    #book.rename(columns={'datepublished' : 'datepublished_booktitle_data'})
    
    #Get only the first published date for a given isbn13
    book = book.sort_values('datepublished')
    book = book.groupby('isbn13').first().reset_index()
    
    return book

def get_merged_printbook_sales_and_booktitles():
    
    '''
    sales colums = ['totalunits', 'price', 'totalrevenue', 'isbn13', 'salesdate','datepublished']
    columns in printbook = ['author', 'title', 'isbn13', 'datepublished']
    '''
    sales = get_printbook_sales_data()
    book = get_printbook_title_data()
    merged_printbook_book = pd.merge(sales, book, on=['isbn13','datepublished'])
    return merged_printbook_book

def get_merged_advances_print_booktitles():
    
    '''
    columns in adv = ['Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
       'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
       'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All']
       
    columns in printbook = ['author', 'title', 'isbn13', 'datepublished']
    '''
    adv = get_advances_data()
    book = get_printbook_title_data()
    merged_adv_print_book = pd.merge(book, adv , left_on ='author' ,right_on='Author(s)')
    
    #get only the rows whose difference between advance date and pubished date is more than 90 days
    merged_adv_print_book = merged_adv_print_book[(merged_adv_print_book['datepublished'] - merged_adv_print_book['Date']).dt.days >=90]
    return merged_adv_print_book

def get_full_merged_advances_printbook_sales():
    
    merged_printbooksales_printbooktitles = get_merged_printbook_sales_and_booktitles()
    merged_advances_printbooktitles = get_merged_advances_print_booktitles()
    full_merge = pd.merge(merged_printbooksales_printbooktitles,
                         merged_advances_printbooktitles,
                         on=['isbn13', 'datepublished'])
    return full_merge

def get_preprocessed_full_merge_advance_printbook_sales(full_merge):
    
    #Filter out on if the datepublished and advance date has more than 90 day difference
    full_merge = full_merge[(full_merge['datepublished'] - full_merge['Date']).dt.days >=90]

    
    #get rows for each isbn13
    for d in full_merge['isbn13']:
        fl = full_merge[full_merge['isbn13']==d]
        #check if there are multiple values for that isbn13
        if fl.shape[0] >1:
            #check if fiction is a rights category among those
            if (fl['Rights Category'] == 'Fiction').any():
                #Keep the fiction one and drop the other ones
                full_merge.drop(fl[fl['Rights Category'] != 'Fiction'].index,inplace=True)
    
    #Taking the max of right's category and keep that
    max_advance_idx = full_merge.groupby('isbn13')['Advance'].idxmax()
    full_merge = full_merge.loc[max_advance_idx]    
    
    return full_merge

def perform_Dr_Samsun_Strategy_of_adding_advances(full_merge):
    
    grouped_merge = full_merge.groupby('isbn13', as_index=False).agg({'Advance': 'sum'})
    full_merge = pd.merge(full_merge, grouped_merge, on='isbn13', how='left')
    full_merge = full_merge.rename(columns={'Advance_y':'advance_amount_sum', 'Advance_x': 'Advance'})
    return full_merge

# %%
full_merge = get_full_merged_advances_printbook_sales()
# Out:
# <ipython-input-2-8486d8a86fd4>:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('sales/printbook_sales.csv')
# <ipython-input-2-8486d8a86fd4>:34: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv('books/booktitle_printbooks_new.csv')
# <ipython-input-2-8486d8a86fd4>:34: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv('books/booktitle_printbooks_new.csv')

# %%
full_merge
# Out:
#              isbn13 datepublished  totalrevenue  totalunits        price
# 0      9.780007e+12    2019-09-24         27984          23  2234.078431  \
# 1      9.780007e+12    2020-03-05       2996384        1125  2536.134694
# 2      9.780008e+12    2018-05-31           899           1   899.000000
# 3      9.780008e+12    2017-07-27             0           0  1216.458333
# 4      9.780008e+12    2017-07-27             0           0  1216.458333
# ...             ...           ...           ...         ...          ...
# 28061  9.798747e+12    2021-05-25         24681          19  1299.000000
# 28062  9.798747e+12    2021-05-25         24681          19  1299.000000
# 28063  9.798747e+12    2021-05-01         97951          49  1999.000000
# 28064  9.798748e+12    2021-05-04         31200          24  1300.000000
# 28065  9.798750e+12    2021-05-10          2699           1  2753.000000
#
#               author_x                                            title_x
# 0           Demi Moore                                         Inside Out  \
# 1        Hilary Mantel                           The Mirror and the Light
# 2        Steven Camden                                    It’s About Love
# 3        Josh Malerman                                    Black Mad Wheel
# 4        Josh Malerman                                    Black Mad Wheel
# ...                ...                                                ...
# 28061     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 28062     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 28063  Nicole Williams                                When All Else Fails
# 28064     Karina Halle           Bright Midnight: A Second-Chance Romance
# 28065   Colin Falconer  AZTEC: the story of Cortes and La Malinche (EP...
#
#               author_y                                            title_y
# 0           Demi Moore                                         Inside Out  \
# 1        Hilary Mantel                           The Mirror and the Light
# 2        Steven Camden                                    It’s About Love
# 3        Josh Malerman                                    Black Mad Wheel
# 4        Josh Malerman                                    Black Mad Wheel
# ...                ...                                                ...
# 28061     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 28062     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 28063  Nicole Williams                                When All Else Fails
# 28064     Karina Halle           Bright Midnight: A Second-Chance Romance
# 28065   Colin Falconer  AZTEC: the story of Cortes and La Malinche (EP...
#
#             Rights Category  ...
# 0               Non-fiction  ...  \
# 1      International rights  ...
# 2      International rights  ...
# 3                   Fiction  ...
# 4                   Fiction  ...
# ...                     ...  ...
# 28061          Audio rights  ...
# 28062       Digital Fiction  ...
# 28063            Children's  ...
# 28064               Fiction  ...
# 28065  International rights  ...
#
#                                               Publishers
# 0      ['Jonathan Burnham', 'Harper', 'Jennifer Barth...  \
# 1      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 2      ['Nick Lake', 'Harper UK', 'Cathryn Summerhaye...
# 3      ['Michael Braff', 'Del Rey', 'Kristin Nelson',...
# 4      ['Lee Boudreaux', 'Ecco', 'Emma Coode', 'Voyag...
# ...                                                  ...
# 28061                                               NONE
# 28062                    ['Erin George', 'Henery Press']
# 28063  ['Phoebe Yeh', "Crown Children's", 'Jane Dyste...
# 28064  ['Latoya Smith', 'Grand Central', 'Scott Waxma...
# 28065  ['Anthony Cheetham', 'Nicolas Cheetham', 'Corv...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 0                              Harper  625000.0         NaN    NaN        NaN  \
# 1                                 NaN   24500.5         NaN    NaN        NaN
# 2                              Harper  375000.0         YES    NaN        NaN
# 3                                 NaN  175000.0         YES    YES        NaN
# 4                                 NaN  375000.0         YES    NaN        NaN
# ...                               ...       ...         ...    ...        ...
# 28061                             NaN   24500.5         NaN    NaN        NaN
# 28062                             NaN   24500.5         NaN    NaN        YES
# 28063                             NaN  175000.0         NaN    NaN        NaN
# 28064                             NaN   74500.0         NaN    NaN        NaN
# 28065                             NaN  175000.0         NaN    NaN        NaN
#
#        Self Publishing Debut Series
# 0                  NaN   NaN    NaN  \
# 1                  NaN   NaN    NaN
# 2                  NaN   YES    NaN
# 3                  NaN   NaN    NaN
# 4                  NaN   YES    NaN
# ...                ...   ...    ...
# 28061              NaN   NaN    NaN
# 28062              NaN   NaN    NaN
# 28063              NaN   NaN    NaN
# 28064              YES   NaN    NaN
# 28065              NaN   NaN    NaN
#
#                                                      All
# 0      Demi Moore's currently untitled book, chronicl...
# 1      Polish rights to Hilary Mantel's A PLACE OF GR...
# 2      Spoken word poet Steven Camden's TAPE, a debut...
# 3      Bram Stoker Award-nominee Josh Malerman's UNBU...
# 4      The lead singer/songwriter of the rock band Th...
# ...                                                  ...
# 28061  Tonya Kappes's FIXIN' TO DIE, in the Kenni Low...
# 28062  USA Today bestselling author Tonya Kappes's ne...
# 28063  Nicole Williams's BET YOU CAN'T, featuring the...
# 28064  Karina Halle's Artists Trilogy, featuring the ...
# 28065  Colin Falconer's SILK ROAD, pitched as aimed a...
#
# [28066 rows x 24 columns]

# %%
p = get_preprocessed_full_merge_advance_printbook_sales(full_merge)

# %%
p.shape
# Out:
# (14118, 24)

# %%
import pandas as pd
import re

def preprocess_names(df, Column_Name):
    #Remove space if the first letter of the word is a space
    
    df['temp_Column_Name'] = df[Column_Name]
    df['temp_Column_Name'] = df['temp_Column_Name'].str.lstrip()
    
    #Remove single letter in the Names
    #df[Column_Name] = df[Column_Name].str.replace(r'\b[A-Za-z]\b', '')
    df['temp_Column_Name'] = df['temp_Column_Name'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 1]))
    
    df['temp_Column_Name'] = df['temp_Column_Name'].apply(lambda x: re.sub(r'\b[A-Z]\.\s*', '', x))
    
    #Remove names in brackets
    #df[Column_Name] = df[Column_Name].str.replace(r'\s?\([^()]*\)', '')
    df['temp_Column_Name'] = df['temp_Column_Name'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))
    
    rwords = ['Doctor','Professor','Captain','Jr','Sr','III','II', 'IV']
    for word in rwords:
        df.loc[:, 'temp_Column_Name'] = df['temp_Column_Name'].str.replace(word,"")
        
    df['temp_Column_Name'] = df['temp_Column_Name'].str.lstrip()
    
    df['First Name'] = df['temp_Column_Name'].str.split(" ", expand=True)[0]
    df['Last Name'] = df['temp_Column_Name'].str.split().str[-1]
    df.drop(columns=['temp_Column_Name'], inplace=True)
    return df

# %%
p.shape
# Out:
# (14118, 24)

# %%
dx = preprocess_names(p,'author_x')

# %%
dx.shape
# Out:
# (14118, 26)

# %%
import gender_guesser.detector as gender

d = gender.Detector(case_sensitive=False)
dx['gender'] = dx['First Name'].apply(lambda x : d.get_gender(x))

# %%
dg = dx.copy()
dg1 = dx.copy()

# %%
from ethnicolr import pred_fl_reg_name

px = pred_fl_reg_name(dg,'Last Name', 'First Name')
dg1 = dg1.merge(px, on=['Last Name', 'First Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-662e2b9f8cc5> in <module>
#       2
#       3 px = pred_fl_reg_name(dg,'Last Name', 'First Name')
# ----> 4 dg1 = dg1.merge(px, on=['Last Name', 'First Name','gender'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9846         from pandas.core.reshape.merge import merge
#    9847
# -> 9848         return merge(
#    9849             self,
#    9850             right,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     142     validate: str | None = None,
#     143 ) -> DataFrame:
# --> 144     op = _MergeOperation(
#     145         left,
#     146         right,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     731             self.right_join_keys,
#     732             self.join_names,
# --> 733         ) = self._get_merge_keys()
#     734
#     735         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1207                         #  the latter of which will raise
#    1208                         lk = cast(Hashable, lk)
# -> 1209                         left_keys.append(left._get_label_or_level_values(lk))
#    1210                         join_names.append(lk)
#    1211                     else:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#
# KeyError: 'gender'

# %%
final_df = dg1[['isbn13_x', 'datepublished_x', 'totalrevenue_x',
               'totalunits_x','price_x', 'author_x_x', 'title_x_x',
               'Rights Category_x', 'Genre_x', 'Date_x', 'Author(s)_x', 'Title_x',
                'Publishers_x', 'Big Publishing House Affilation_x', 'Advance_x',
               'Competition_x', 'Awards_x', 'Bestseller_x', 'Self Publishing_x',
               'Debut_x', 'Series_x', 'All_x', 'First Name', 'Last Name', 'gender_x',
                'asian', 'hispanic', 'nh_black', 'nh_white', 'race'
               ]]

# %%
final_df = final_df.rename(columns={
    'isbn13_x': 'isbn13',
    'datepublished_x': 'datepublished', 
    'totalrevenue_x' : 'totalrevenue',
    'totalunits_x':'totalunits',
    'price_x':'price',
    'author_x_x':'author',
    'title_x_x' : 'title',
    'Rights Category_x':'Rights Category', 
    'Genre_x':'Genre', 
    'Date_x': 'Date', 
    'Author(s)_x':'Author(s)',
    'Title_x':'Title',
    'Publishers_x':'Publishers', 
    'Big Publishing House Affilation_x':'Big Publishing House Affilation', 
    'Advance_x':'Advance',
    'Competition_x':'Competition', 
    'Awards_x':'Awards', 
    'Bestseller_x':'Bestseller', 
    'Self Publishing_x':'Self Publishing',
    'Debut_x':'Debut', 
    'Series_x':'Series', 
    'All_x':'All', 
    'gender_x':'gender'
})

# %%
final_df.to_csv('full_merge_advance_max_with_ethnicity_and_gender.csv')

# %%
eth.to_csv('full_merge_advance_max_with_ethnicity_and_gender.csv')

# %%
q= perform_Dr_Samsun_Strategy_of_adding_advances(full_merge)

# %%
filtered_q = q[q.groupby('isbn13')['isbn13'].transform('count') > 1]

# %%
k=0
n=20
z = pd.DataFrame(columns=q.columns)
for x in q['isbn13']:
    if q[q['isbn13'] ==x].shape[0] >1:
        z = pd.concat([z, q[q['isbn13'] ==x]])
        print(x)
        k+=1
    if k==n:
        break
# Out:
# 9780007530090.0
# 9780007530090.0
# 9780008152352.0
# 9780008152352.0
# 9780008152420.0
# 9780008152420.0
# 9780008152420.0
# 9780008158828.0
# 9780008158828.0
# 9780008180065.0
# 9780008180065.0
# 9780008180065.0
# 9780008180089.0
# 9780008180089.0
# 9780008180089.0
# 9780008180119.0
# 9780008180119.0
# 9780008180119.0
# 9780008180119.0
# 9780008192211.0

# %%
z.to_csv('duplicate_isbn13_file.csv')

# %%
q[q['isbn13'] ==9780008158828.0].iloc[:,:17]
# Out:
#           isbn13 datepublished  totalrevenue  totalunits        price
# 18  9.780008e+12    2018-09-20        271785         213  1327.378698  \
# 19  9.780008e+12    2018-09-20        271785         213  1327.378698
#
#       author_x                   title_x    author_y
# 18  Kiera Cass  Untitled Standalone Cass  Kiera Cass  \
# 19  Kiera Cass  Untitled Standalone Cass  Kiera Cass
#
#                      title_y Rights Category                Genre       Date
# 18  Untitled Standalone Cass      Children's  Young Adult Fiction 2013-03-12  \
# 19  Untitled Standalone Cass      Children's  Young Adult Fiction 2010-06-22
#
#      Author(s)          Title
# 18  Kiera Cass           NONE  \
# 19  Kiera Cass  THE SELECTION
#
#                                            Publishers
# 18  ['Erica Sussman', 'Harper Teen', 'Elana Roth',...  \
# 19  ['Erica Sussman', "Harper Children's", 'Elana ...
#
#    Big Publishing House Affilation   Advance
# 18                          Harper  175000.0
# 19                          Harper  175000.0

# %%
p.to_csv('full_merge_fiction_max_advance_strategy.csv')

# %%
print(p.shape)
print(len(p['isbn13'].unique()))
# Out:
# (14118, 24)
# 14118

# %%
q= perform_Dr_Samsun_Strategy_of_adding_advances(full_merge)

# %%
q.to_csv('full_merge_advance_sum_strategy.csv')

# %%
q = q.rename(columns={'Advance_y':'advance_amount_sum'})

# %%
q[q['isbn13']==9780008152420.0].iloc[:,:17]
# Out:
#           isbn13 datepublished  totalrevenue  totalunits        price
# 14  9.780008e+12    2020-04-16         74553          55  1433.966851  \
# 15  9.780008e+12    2020-04-16         74553          55  1433.966851
#
#          author_x      title_x       author_y      title_y Rights Category
# 14  Mark Lawrence  Holy Sister  Mark Lawrence  Holy Sister         Fiction  \
# 15  Mark Lawrence  Holy Sister  Mark Lawrence  Holy Sister         Fiction
#
#               Genre       Date      Author(s)             Title
# 14  Sci-Fi/ Fantasy 2015-06-24  Mark Lawrence        RED SISTER  \
# 15  Sci-Fi/ Fantasy 2010-04-08  Mark Lawrence  PRINCE OF THORNS
#
#                                            Publishers
# 14  ['Diana Gill', 'Ace', 'Jane Johnson', 'Voyager...  \
# 15  ['Ginjer Buchanan', 'Roc', 'Ian Drury', 'Sheil...
#
#    Big Publishing House Affilation   Advance
# 14                             NaN  375000.0
# 15                          Harper   74500.0

# %%
full_merge = full_merge[(full_merge['datepublished'] - full_merge['Date']).dt.days >=90]

# %%
print(full_merge.shape)
print(len(full_merge['isbn13'].unique()))
# Out:
# (24425, 24)
# 14118

# %%
k = 0
for d in full_merge['isbn13']:
    if full_merge[full_merge['isbn13']==d].shape[0] >2:
        print(d)
        k+=1
    if k==5:
        break
# Out:
# 9780008152420.0
# 9780008152420.0
# 9780008152420.0
# 9780008180065.0
# 9780008180065.0

# %%
full_merge[full_merge['isbn13']==9780008152420.0].iloc[:, : 17]
# Out:
#           isbn13 datepublished  totalrevenue  totalunits        price
# 21  9.780008e+12    2020-04-16         74553          55  1433.966851  \
# 22  9.780008e+12    2020-04-16         74553          55  1433.966851
# 23  9.780008e+12    2020-04-16         74553          55  1433.966851
#
#          author_x      title_x       author_y      title_y  Rights Category
# 21  Mark Lawrence  Holy Sister  Mark Lawrence  Holy Sister  Digital Fiction  \
# 22  Mark Lawrence  Holy Sister  Mark Lawrence  Holy Sister          Fiction
# 23  Mark Lawrence  Holy Sister  Mark Lawrence  Holy Sister          Fiction
#
#               Genre       Date      Author(s)             Title
# 21         Thriller 2018-11-27  Mark Lawrence     ONE WORD KILL  \
# 22  Sci-Fi/ Fantasy 2015-06-24  Mark Lawrence        RED SISTER
# 23  Sci-Fi/ Fantasy 2010-04-08  Mark Lawrence  PRINCE OF THORNS
#
#                                            Publishers
# 21  ['Jack Butler', 'Thomas & Mercer', 'Ian Drury'...  \
# 22  ['Diana Gill', 'Ace', 'Jane Johnson', 'Voyager...
# 23  ['Ginjer Buchanan', 'Roc', 'Ian Drury', 'Sheil...
#
#    Big Publishing House Affilation   Advance
# 21                             NaN  175000.0
# 22                             NaN  375000.0
# 23                          Harper   74500.0

# %%
for d in full_merge['isbn13']:
    fl = full_merge[full_merge['isbn13']==d]
    if fl.shape[0] >1:
        if (fl['Rights Category'] == 'Fiction').any():
            full_merge.drop(fl[fl['Rights Category'] != 'Fiction'].index,inplace=True)

# %%
full_merge
# Out:
#              isbn13 datepublished  totalrevenue  totalunits        price
# 0      9.780007e+12    2019-09-24         27984          23  2234.078431  \
# 1      9.780007e+12    2020-03-05       2996384        1125  2536.134694
# 2      9.780008e+12    2018-05-31           899           1   899.000000
# 5      9.780008e+12    2017-07-27             0           0  1216.458333
# 6      9.780008e+12    2017-07-27             0           0  1216.458333
# ...             ...           ...           ...         ...          ...
# 36745  9.798747e+12    2021-05-25         24681          19  1299.000000
# 36746  9.798747e+12    2021-05-25         24681          19  1299.000000
# 36747  9.798747e+12    2021-05-01         97951          49  1999.000000
# 36748  9.798748e+12    2021-05-04         31200          24  1300.000000
# 36749  9.798750e+12    2021-05-10          2699           1  2753.000000
#
#               author_x                                            title_x
# 0           Demi Moore                                         Inside Out  \
# 1        Hilary Mantel                           The Mirror and the Light
# 2        Steven Camden                                    It’s About Love
# 5        Josh Malerman                                    Black Mad Wheel
# 6        Josh Malerman                                    Black Mad Wheel
# ...                ...                                                ...
# 36745     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 36746     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 36747  Nicole Williams                                When All Else Fails
# 36748     Karina Halle           Bright Midnight: A Second-Chance Romance
# 36749   Colin Falconer  AZTEC: the story of Cortes and La Malinche (EP...
#
#               author_y                                            title_y
# 0           Demi Moore                                         Inside Out  \
# 1        Hilary Mantel                           The Mirror and the Light
# 2        Steven Camden                                    It’s About Love
# 5        Josh Malerman                                    Black Mad Wheel
# 6        Josh Malerman                                    Black Mad Wheel
# ...                ...                                                ...
# 36745     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 36746     Tonya Kappes    Post Mortem: A Mail Carrier Cozy Mystery Book 6
# 36747  Nicole Williams                                When All Else Fails
# 36748     Karina Halle           Bright Midnight: A Second-Chance Romance
# 36749   Colin Falconer  AZTEC: the story of Cortes and La Malinche (EP...
#
#             Rights Category  ...
# 0               Non-fiction  ...  \
# 1      International rights  ...
# 2      International rights  ...
# 5                   Fiction  ...
# 6                   Fiction  ...
# ...                     ...  ...
# 36745          Audio rights  ...
# 36746       Digital Fiction  ...
# 36747            Children's  ...
# 36748               Fiction  ...
# 36749  International rights  ...
#
#                                               Publishers
# 0      ['Jonathan Burnham', 'Harper', 'Jennifer Barth...  \
# 1      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 2      ['Nick Lake', 'Harper UK', 'Cathryn Summerhaye...
# 5      ['Michael Braff', 'Del Rey', 'Kristin Nelson',...
# 6      ['Lee Boudreaux', 'Ecco', 'Emma Coode', 'Voyag...
# ...                                                  ...
# 36745                                               NONE
# 36746                    ['Erin George', 'Henery Press']
# 36747  ['Phoebe Yeh', "Crown Children's", 'Jane Dyste...
# 36748  ['Latoya Smith', 'Grand Central', 'Scott Waxma...
# 36749  ['Anthony Cheetham', 'Nicolas Cheetham', 'Corv...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 0                              Harper  625000.0         NaN    NaN        NaN  \
# 1                                 NaN   24500.5         NaN    NaN        NaN
# 2                              Harper  375000.0         YES    NaN        NaN
# 5                                 NaN  175000.0         YES    YES        NaN
# 6                                 NaN  375000.0         YES    NaN        NaN
# ...                               ...       ...         ...    ...        ...
# 36745                             NaN   24500.5         NaN    NaN        NaN
# 36746                             NaN   24500.5         NaN    NaN        YES
# 36747                             NaN  175000.0         NaN    NaN        NaN
# 36748                             NaN   74500.0         NaN    NaN        NaN
# 36749                             NaN  175000.0         NaN    NaN        NaN
#
#        Self Publishing Debut Series
# 0                  NaN   NaN    NaN  \
# 1                  NaN   NaN    NaN
# 2                  NaN   YES    NaN
# 5                  NaN   NaN    NaN
# 6                  NaN   YES    NaN
# ...                ...   ...    ...
# 36745              NaN   NaN    NaN
# 36746              NaN   NaN    NaN
# 36747              NaN   NaN    NaN
# 36748              YES   NaN    NaN
# 36749              NaN   NaN    NaN
#
#                                                      All
# 0      Demi Moore's currently untitled book, chronicl...
# 1      Polish rights to Hilary Mantel's A PLACE OF GR...
# 2      Spoken word poet Steven Camden's TAPE, a debut...
# 5      Bram Stoker Award-nominee Josh Malerman's UNBU...
# 6      The lead singer/songwriter of the rock band Th...
# ...                                                  ...
# 36745  Tonya Kappes's FIXIN' TO DIE, in the Kenni Low...
# 36746  USA Today bestselling author Tonya Kappes's ne...
# 36747  Nicole Williams's BET YOU CAN'T, featuring the...
# 36748  Karina Halle's Artists Trilogy, featuring the ...
# 36749  Colin Falconer's SILK ROAD, pitched as aimed a...
#
# [28066 rows x 24 columns]

# %%
full_merge[full_merge['isbn13']==9780008180065.0].iloc[:, : 17]
# Out:
#           isbn13 datepublished  totalrevenue  totalunits   price
# 35  9.780008e+12    2018-06-18         19534          22  886.92  \
# 36  9.780008e+12    2018-06-18         19534          22  886.92
#
#         author_x                               title_x      author_y
# 35  Jay Kristoff  Godsgrave (The Nevernight Chronicle)  Jay Kristoff  \
# 36  Jay Kristoff  Godsgrave (The Nevernight Chronicle)  Jay Kristoff
#
#                                  title_y Rights Category            Genre
# 35  Godsgrave (The Nevernight Chronicle)         Fiction  Sci-Fi/ Fantasy  \
# 36  Godsgrave (The Nevernight Chronicle)         Fiction  Sci-Fi/ Fantasy
#
#          Date     Author(s)        Title
# 35 2014-09-19  Jay Kristoff         NONE  \
# 36 2011-01-26  Jay Kristoff  STORMDANCER
#
#                                            Publishers
# 35  ['Peter Wolverton', 'Thomas Dunne Books', 'Mat...  \
# 36  ['Peter Wolverton', 'Thomas Dunne Books', 'Mat...
#
#    Big Publishing House Affilation   Advance
# 35                             NaN  175000.0
# 36                             NaN  175000.0

# %%
x = full_merge[full_merge['isbn13']==9780008180065.0].iloc[:, : 17]

# %%
x
# Out:
#           isbn13 datepublished  totalrevenue  totalunits   price
# 34  9.780008e+12    2018-06-18         19534          22  886.92  \
# 35  9.780008e+12    2018-06-18         19534          22  886.92
# 36  9.780008e+12    2018-06-18         19534          22  886.92
#
#         author_x                               title_x      author_y
# 34  Jay Kristoff  Godsgrave (The Nevernight Chronicle)  Jay Kristoff  \
# 35  Jay Kristoff  Godsgrave (The Nevernight Chronicle)  Jay Kristoff
# 36  Jay Kristoff  Godsgrave (The Nevernight Chronicle)  Jay Kristoff
#
#                                  title_y Rights Category                Genre
# 34  Godsgrave (The Nevernight Chronicle)      Children's  Young Adult Fiction  \
# 35  Godsgrave (The Nevernight Chronicle)         Fiction      Sci-Fi/ Fantasy
# 36  Godsgrave (The Nevernight Chronicle)         Fiction      Sci-Fi/ Fantasy
#
#          Date     Author(s)        Title
# 34 2016-03-08  Jay Kristoff     LIFEL1K3  \
# 35 2014-09-19  Jay Kristoff         NONE
# 36 2011-01-26  Jay Kristoff  STORMDANCER
#
#                                            Publishers
# 34  ['Melanie Cecka Nolan', "Knopf Children's", 'J...  \
# 35  ['Peter Wolverton', 'Thomas Dunne Books', 'Mat...
# 36  ['Peter Wolverton', 'Thomas Dunne Books', 'Mat...
#
#    Big Publishing House Affilation   Advance
# 34                             NaN  375000.0
# 35                             NaN  175000.0
# 36                             NaN  175000.0

# %%
sales = get_printbook_sales_data()
# Out:
# <ipython-input-3-e2ad772929ec>:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('sales/printbook_sales.csv')

# %%
print(len(sales['isbn13']), len(sales['isbn13'].unique()))
print(len(sales['datepublished']), len(sales['datepublished'].unique()))
# Out:
# 41445107 194035
# 41445107 6802

# %%
xsales =sales.groupby(['isbn13','datepublished'], as_index=False).agg({'totalrevenue':'sum', 'totalunits':'sum', 'price':'mean'})

# %%
adv = get_advances_data()

# %%
print(adv.shape)
print(len(adv['Author(s)'].unique()))
# Out:
# (34297, 15)
# 17796

# %%
adv[adv['Author(s)'] =='Josh Malerman']
# Out:
#        Rights Category            Genre       Date      Author(s)
# 45936          Fiction   General/ Other 2019-11-11  Josh Malerman  \
# 54187          Fiction         Thriller 2019-03-18  Josh Malerman
# 80059          Fiction  Sci-Fi/ Fantasy 2017-03-06  Josh Malerman
# 130491         Fiction           Horror 2012-08-10  Josh Malerman
#
#                                                     Title
# 45936   ['SPIN A BLACK YARN', 'GOBLIN', 'A HOUSE AT TH...  \
# 54187                       ['MALORIE', 'MUSICAL CHAIRS']
# 80059                                        UNBURY CAROL
# 130491                                           BIRD BOX
#
#                                                Publishers
# 45936   ['Tricia Narwani', 'Del Rey', 'Kristin Nelson'...  \
# 54187   ['Tricia Narwani', 'Del Rey', 'Kristin Nelson'...
# 80059   ['Michael Braff', 'Del Rey', 'Kristin Nelson',...
# 130491  ['Lee Boudreaux', 'Ecco', 'Emma Coode', 'Voyag...
#
#        Big Publishing House Affilation   Advance Competition Awards
# 45936                              NaN  175000.0         NaN    NaN  \
# 54187                              NaN  625000.0         NaN    NaN
# 80059                              NaN  175000.0         YES    YES
# 130491                             NaN  375000.0         YES    NaN
#
#        Bestseller Self Publishing Debut Series
# 45936         YES             NaN   NaN    NaN  \
# 54187         YES             NaN   NaN    YES
# 80059         NaN             NaN   NaN    NaN
# 130491        NaN             NaN   YES    NaN
#
#                                                       All
# 45936   NYT-bestselling author of BIRD BOX Josh Malerm...
# 54187   NYT-bestselling author of BIRD BOX Josh Malerm...
# 80059   Bram Stoker Award-nominee Josh Malerman's UNBU...
# 130491  The lead singer/songwriter of the rock band Th...

# %%
book = get_printbook_title_data()
# Out:
# <ipython-input-3-e2ad772929ec>:26: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   book = pd.read_csv('books/booktitle_printbooks_new.csv')

# %%
book_sorted = book.sort_values('datepublished')
book_filtered = book_sorted.groupby('isbn13').first().reset_index()

# %%
book_filtered[book_filtered['author'] =='Josh Malerman']
# Out:
#               isbn13         author
# 41      9.780008e+12  Josh Malerman  \
# 9873    9.780399e+12  Josh Malerman
# 9874    9.780399e+12  Josh Malerman
# 16173   9.780593e+12  Josh Malerman
# 16540   9.780593e+12  Josh Malerman
# 16541   9.780593e+12  Josh Malerman
# 48352   9.781409e+12  Josh Malerman
# 49968   9.781433e+12  Josh Malerman
# 63253   9.781525e+12  Josh Malerman
# 63254   9.781525e+12  Josh Malerman
# 98864   9.781721e+12  Josh Malerman
# 105517  9.781733e+12  Josh Malerman
# 162876  9.783734e+12  Josh Malerman
# 166350  9.788551e+12  Josh Malerman
#
#                                                     title datepublished
# 41                                        Black Mad Wheel    2017-07-27
# 9873                                Unbury Carol: A Novel    2018-04-10
# 9874                                Unbury Carol: A Novel    2019-02-05
# 16173                                    Malorie: A Novel    2020-07-21
# 16540                     A House at the Bottom of a Lake    2021-01-19
# 16541                     Goblin: A Novel in Six Novellas    2021-05-18
# 48352       Malorie: The much-anticipated Bird Box sequel    2019-10-01
# 49968   Unbury Carol (Thorndike Press Large Print Bill...    2018-10-03
# 63253                                 Inspection: A Novel    2019-03-19
# 63254                                 Inspection: A Novel    2019-09-17
# 98864                                   Doorbells at Dusk    2018-08-06
# 105517  Miscreations: Gods, Monstrosities & Other Horrors    2020-02-18
# 162876             Bird Box - Schließe deine Augen: Roman    2018-12-17
# 166350  Uma Casa no Fundo de Um Lago (Em Portugues do ...    2018-01-01

# %%
print(book.shape, len(book['isbn13'].unique()), len(book_filtered['isbn13']))
# Out:
# (190400, 4) 189725 189724

# %%
print(sales.shape, adv.shape, book.shape)
# Out:
# (41445107, 6) (34297, 15) (190400, 4)

# %%
merged_sales_book = pd.merge(xsales, book_filtered, on=['isbn13', 'datepublished'])

# %%
print(merged_sales_book.shape)
print(len(merged_sales_book['isbn13'].unique()))
print(len(merged_sales_book['datepublished'].unique()))
# Out:
# (187320, 7)
# 187320
# 2152

# %%
merged_sales_book

#Should I add revenue of books published on different dates
# Out:
#               isbn13 datepublished  totalrevenue  totalunits        price
# 0       9.780007e+12    2006-10-16             0           0  1427.000000  \
# 1       9.780007e+12    2015-09-15         11184          16   699.000000
# 2       9.780007e+12    2014-09-02         46773          67   697.647059
# 3       9.780007e+12    2019-07-20             0           0  2000.000000
# 4       9.780007e+12    2015-09-29          3684           5   703.846154
# ...              ...           ...           ...         ...          ...
# 187315  9.798750e+12    2021-06-18        255813          64  4010.229508
# 187316  9.798750e+12    2021-05-06             0           0   932.333333
# 187317  9.798750e+12    2021-05-06         54298          34  1597.000000
# 187318  9.798750e+12    2021-05-11          6996           6  1166.000000
# 187319  9.798750e+12    2021-05-06          2598           2  1299.000000
#
#                     author                                              title
# 0         Philippa Gregory                                       Virgin Earth
# 1              Stacy Gregg  Stardust and the Daredevil Ponies (Pony Club S...
# 2              Stacy Gregg  Blaze and the Dark Rider (Pony Club Secrets) (...
# 3            Starkey David        Monarchy: From the Middle Ages to Modernity
# 4              Stacy Gregg  Comet and the Champion’s Cup (Pony Club Secret...
# ...                    ...                                                ...
# 187315      Emily Attached  Mental Health Workbook: 6 Books in 1: The Atta...
# 187316        Hans Fallada                             Little man - What now?
# 187317         Tasha Dixon  Dr. Sebi Smoothies Cleanse Book: The Approved ...
# 187318  Diana Robles Pérez                  Vértigo al frío (Spanish Edition)
# 187319      R.J. Patterson      Rogue Commander (Titus Black Thriller series)
#
# [187320 rows x 7 columns]

# %%
adv.columns
# Out:
# Index(['Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All'],
#       dtype='object')

# %%
merged_book_adv = pd.merge(book_filtered, adv, left_on ='author' ,right_on='Author(s)')

# %%
merged_book_adv = merged_book_adv[(merged_book_adv['datepublished'] -merged_book_adv['Date']).dt.days >=90 ]
#merged_book_adv = merged_book_adv[(merged_book_adv['datepublished'] -merged_book_adv['Date']).dt.days <=500 ]
#merged_book_adv = merged_book_adv[merged_book_adv['Title'] !='NONE']

# %%
merged_book_adv['title'] = merged_book_adv['title'].astype('str')
merged_book_adv['Title'] = merged_book_adv['Title'].astype('str')

# %%
merged_book_adv[merged_book_adv['isbn13'] ==9780007466085.0]
#merged_book_adv['isbn13'][20]
# Out:
#          isbn13      author       title datepublished Rights Category   Genre
# 0  9.780007e+12  Demi Moore  Inside Out    2019-09-24     Non-fiction  Memoir  \
#
#         Date   Author(s) Title
# 0 2010-06-08  Demi Moore  NONE  \
#
#                                           Publishers
# 0  ['Jonathan Burnham', 'Harper', 'Jennifer Barth...  \
#
#   Big Publishing House Affilation   Advance Competition Awards Bestseller
# 0                          Harper  625000.0         NaN    NaN        NaN  \
#
#   Self Publishing Debut Series
# 0             NaN   NaN    NaN  \
#
#                                                  All
# 0  Demi Moore's currently untitled book, chronicl...

# %%
merged_book_adv[merged_book_adv['isbn13'] ==9780593156858.0]
merged_book_adv[merged_book_adv['isbn13'] ==9780008363710.0]
# Out:
#            isbn13      author
# 415  9.780008e+12  Robin Hobb  \
# 416  9.780008e+12  Robin Hobb
# 417  9.780008e+12  Robin Hobb
#
#                                                  title datepublished
# 415  Assassin’s Apprentice (The Farseer Trilogy, Bo...    2019-10-03  \
# 416  Assassin’s Apprentice (The Farseer Trilogy, Bo...    2019-10-03
# 417  Assassin’s Apprentice (The Farseer Trilogy, Bo...    2019-10-03
#
#           Rights Category            Genre       Date   Author(s)
# 415          Audio rights             NONE 2014-03-19  Robin Hobb  \
# 416               Fiction  Sci-Fi/ Fantasy 2014-03-15  Robin Hobb
# 417  International rights       UK Fiction 2013-10-17  Robin Hobb
#
#                  Title                                         Publishers
# 415               NONE                                               NONE  \
# 416  FITZ AND THE FOOL  ['Anne Groell', 'Del Rey', 'Chris Lotts', 'The...
# 417  FITZ AND THE FOOL  ['Jane Johnson', 'Harper UK', 'Chris Lotts', '...
#
#     Big Publishing House Affilation   Advance Competition Awards Bestseller
# 415                             NaN   24500.5         NaN    NaN        NaN  \
# 416                             NaN  625000.0         NaN    NaN        NaN
# 417                          Harper  625000.0         NaN    NaN        NaN
#
#     Self Publishing Debut Series
# 415             NaN   NaN    NaN  \
# 416             NaN   NaN    NaN
# 417             NaN   NaN    NaN
#
#                                                    All
# 415  Robin Hobb's TAWNY MAN trilogy, part of her Re...
# 416  Robin Hobb's FITZ AND THE FOOL trilogy, revivi...
# 417  Robin Hobb's new FITZ AND THE FOOL trilogy, re...

# %%
print(merged_book_adv.shape)
print(len(merged_book_adv['isbn13'].unique()))
# Out:
# (20670, 19)
# 12287

# %%
from fuzzywuzzy import fuzz

merged_book_adv['title_match_ratio'] = merged_book_adv.apply(lambda row : 
                                                            fuzz.ratio(row['title'],row['Title']), axis=1)

# %%
max_scores = merged_book_adv.groupby('isbn13')['title_match_ratio'].max().reset_index()

# Merge with the original dataframe to retain the corresponding rows
df_filtered = pd.merge(merged_book_adv, max_scores, on=['isbn13', 'title_match_ratio'], how='inner')

# %%
merged_book_adv['title_match_ratio'] = merged_book_adv.apply(lambda row : 
                                                            fuzz.partial_ratio(row['title'],row['Title']), axis=1)

# %%
max_scores = merged_book_adv.groupby('isbn13')['title_match_ratio'].max().reset_index()

# Merge with the original dataframe to retain the corresponding rows
df_filtered = pd.merge(merged_book_adv, max_scores, on=['isbn13', 'title_match_ratio'], how='inner')

# %%
merged_book_adv['title_match_ratio'] = merged_book_adv.apply(lambda row : 
                                                            fuzz.token_sort_ratio(row['title'],row['Title']), axis=1)

# %%
max_scores = merged_book_adv.groupby('isbn13')['title_match_ratio'].max().reset_index()

# Merge with the original dataframe to retain the corresponding rows
df_filtered = pd.merge(merged_book_adv, max_scores, on=['isbn13', 'title_match_ratio'], how='inner')

# %%
df_filtered = df_filtered[df_filtered['Title'] != 'NONE']

# %%
max_scores = merged_book_adv.groupby('isbn13')['title_match_ratio'].max().reset_index()

# Merge with the original dataframe to retain the corresponding rows
df_filtered = pd.merge(merged_book_adv, max_scores, on=['isbn13', 'title_match_ratio'], how='inner')

# %%
print(df_filtered.shape)
print(len(df_filtered['isbn13'].unique()))
# Out:
# (11722, 20)
# 11722

# %%
df_filtered
# Out:
#              isbn13            author
# 1      9.780007e+12     Hilary Mantel  \
# 2      9.780008e+12     Hilary Mantel
# 3      9.781251e+12     Hilary Mantel
# 4      9.781251e+12     Hilary Mantel
# 5      9.781433e+12     Hilary Mantel
# ...             ...               ...
# 15813  9.798709e+12     Melissa Moore
# 15814  9.798712e+12  Michelle Johnson
# 15815  9.798713e+12     Jaime Salazar
# 15816  9.798730e+12   Christy Barritt
# 15818  9.798745e+12   Cristin Terrill
#
#                                                    title datepublished
# 1                               The Mirror and the Light    2020-03-05  \
# 2      Mantel Pieces: The New Book from The Sunday Ti...    2020-10-06
# 3              Wolf Hall: A Novel (Wolf Hall Trilogy, 1)    2021-05-04
# 4      Bring Up the Bodies: A Novel (Wolf Hall Trilog...    2021-05-04
# 5      The Mirror & the Light (Thorndike Press Large ...    2020-04-15
# ...                                                  ...           ...
# 15813  KETO DIET FOR WOMEN OVER 50: Learn the Healthi...    2021-02-14
# 15814  The New Mediterranean Diet Cookbook 2021: A De...    2021-02-20
# 15815  Legion of the Lost: The true experience of an ...    2021-02-24
# 15816  Rocco: a clean romantic suspense novel (Lanter...    2021-03-29
# 15818                                 All Our Yesterdays    2013-09-03
#
#             Rights Category                Genre       Date         Author(s)
# 1      International rights              Fiction 2013-08-30     Hilary Mantel  \
# 2      International rights              Fiction 2013-08-30     Hilary Mantel
# 3      International rights              Fiction 2013-08-30     Hilary Mantel
# 4      International rights              Fiction 2013-08-30     Hilary Mantel
# 5      International rights              Fiction 2013-08-30     Hilary Mantel
# ...                     ...                  ...        ...               ...
# 15813  International rights          Non-fiction 2010-12-20     Melissa Moore
# 15814          Audio rights                 NONE 2014-10-01  Michelle Johnson
# 15815           Non-fiction              History 2020-04-15     Jaime Salazar
# 15816               Fiction       Mystery/ Crime 2012-06-27   Christy Barritt
# 15818            Children's  Young Adult Fiction 2012-03-02   Cristin Terrill
#
#                                                    Title
# 1                              A PLACE OF GREATER SAFETY  \
# 2                              A PLACE OF GREATER SAFETY
# 3                              A PLACE OF GREATER SAFETY
# 4                              A PLACE OF GREATER SAFETY
# 5                              A PLACE OF GREATER SAFETY
# ...                                                  ...
# 15813                                  SHATTERED SILENCE
# 15814                                           DIVINITY
# 15815                                     MUTINY OF RAGE
# 15816  ['KEY WITNESS', 'LETHAL JUSTICE', 'FINAL JUSTI...
# 15818                                 ALL OUR YESTERDAYS
#
#                                               Publishers
# 1      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  \
# 2      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 3      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 4      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 5      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# ...                                                  ...
# 15813                          ['Asmita Sathe', 'Mehta']
# 15814                                               NONE
# 15815  ['Jake Bonar', 'Rowman & Littlefield', 'Letici...
# 15816  ['Tina James', 'Love Inspired', 'Joyce Hart', ...
# 15818  ['Emily Meehan', 'Disney-Hyperion', 'Diana Fox...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 1                                 NaN   24500.5         NaN    NaN        NaN  \
# 2                                 NaN   24500.5         NaN    NaN        NaN
# 3                                 NaN   24500.5         NaN    NaN        NaN
# 4                                 NaN   24500.5         NaN    NaN        NaN
# 5                                 NaN   24500.5         NaN    NaN        NaN
# ...                               ...       ...         ...    ...        ...
# 15813                             NaN   24500.5         NaN    NaN        NaN
# 15814                             NaN   24500.5         NaN    NaN        NaN
# 15815                             NaN   24500.5         NaN    NaN        NaN
# 15816                             NaN   24500.5         NaN    NaN        NaN
# 15818                             NaN  375000.0         YES    NaN        NaN
#
#       Self Publishing Debut Series
# 1                 NaN   NaN    NaN  \
# 2                 NaN   NaN    NaN
# 3                 NaN   NaN    NaN
# 4                 NaN   NaN    NaN
# 5                 NaN   NaN    NaN
# ...               ...   ...    ...
# 15813             NaN   NaN    NaN
# 15814             NaN   NaN    NaN
# 15815             NaN   NaN    NaN
# 15816             NaN   NaN    NaN
# 15818             NaN   YES    NaN
#
#                                                      All  title_match_ratio
# 1      Polish rights to Hilary Mantel's A PLACE OF GR...                 37
# 2      Polish rights to Hilary Mantel's A PLACE OF GR...                 29
# 3      Polish rights to Hilary Mantel's A PLACE OF GR...                 29
# 4      Polish rights to Hilary Mantel's A PLACE OF GR...                 25
# 5      Polish rights to Hilary Mantel's A PLACE OF GR...                 16
# ...                                                  ...                ...
# 15813  Melissa Moore's SHATTERED SILENCE: The Untold ...                  8
# 15814  Michelle Johnson's DIVINITY, book one in The D...                  7
# 15815  Houston-based immigration lawyer Jaime Salazar...                 17
# 15816  Christy Barritt's KEY WITNESS, when a woman st...                 27
# 15818  Cristin Terrill's debut ALL OUR YESTERDAYS, pi...                100
#
# [11722 rows x 20 columns]

# %%
k=0
for d in df_filtered['isbn13']:
    if df_filtered[df_filtered['isbn13'] == d].shape[0] >1:
        print(df_filtered[df_filtered['isbn13'] == d].index)
        df_filtered = df_filtered.drop(index=df_filtered[df_filtered['isbn13'] == d].index)

# %%
df_filtered[df_filtered['isbn13'] ==9780008245009.0]
df_filtered[df_filtered['title_match_ratio'] >=40]
# Out:
#              isbn13            author
# 8      9.780399e+12     Josh Malerman  \
# 9      9.780399e+12     Josh Malerman
# 10     9.780593e+12     Josh Malerman
# 11     9.780593e+12     Josh Malerman
# 13     9.781409e+12     Josh Malerman
# ...             ...               ...
# 15785  9.798618e+12  Juliette Sobanet
# 15786  9.798624e+12  Juliette Sobanet
# 15789  9.798682e+12    Lynne Connolly
# 15795  9.798639e+12      Anju Gattani
# 15818  9.798745e+12   Cristin Terrill
#
#                                                title datepublished
# 8                              Unbury Carol: A Novel    2018-04-10  \
# 9                              Unbury Carol: A Novel    2019-02-05
# 10                                  Malorie: A Novel    2020-07-21
# 11                   A House at the Bottom of a Lake    2021-01-19
# 13     Malorie: The much-anticipated Bird Box sequel    2019-10-01
# ...                                              ...           ...
# 15785             Dancing with Paris (City of Light)    2019-04-06
# 15786        Midnight Train to Paris (City of Light)    2019-04-07
# 15789  A Whisper of Treason (The Daring Dersinghams)    2020-09-02
# 15795                Duty and Desire (Winds of Fire)    2020-05-01
# 15818                             All Our Yesterdays    2013-09-03
#
#        Rights Category                Genre       Date         Author(s)
# 8              Fiction      Sci-Fi/ Fantasy 2017-03-06     Josh Malerman  \
# 9              Fiction      Sci-Fi/ Fantasy 2017-03-06     Josh Malerman
# 10             Fiction             Thriller 2019-03-18     Josh Malerman
# 11             Fiction       General/ Other 2019-11-11     Josh Malerman
# 13             Fiction             Thriller 2019-03-18     Josh Malerman
# ...                ...                  ...        ...               ...
# 15785  Digital Fiction              Romance 2013-01-18  Juliette Sobanet
# 15786  Digital Fiction              Romance 2013-01-18  Juliette Sobanet
# 15789  Digital Fiction              Romance 2018-06-12    Lynne Connolly
# 15795  Digital Fiction              General 2017-06-26      Anju Gattani
# 15818       Children's  Young Adult Fiction 2012-03-02   Cristin Terrill
#
#                                                    Title
# 8                                           UNBURY CAROL  \
# 9                                           UNBURY CAROL
# 10                         ['MALORIE', 'MUSICAL CHAIRS']
# 11     ['SPIN A BLACK YARN', 'GOBLIN', 'A HOUSE AT TH...
# 13                         ['MALORIE', 'MUSICAL CHAIRS']
# ...                                                  ...
# 15785                            MIDNIGHT TRAIN TO PARIS
# 15786                            MIDNIGHT TRAIN TO PARIS
# 15789                        THE GIRL WITH THE PEARL PIN
# 15795  ['ONCE AND FOR ALL', 'DUTY AND DESIRE', 'NEVER...
# 15818                                 ALL OUR YESTERDAYS
#
#                                               Publishers
# 8      ['Michael Braff', 'Del Rey', 'Kristin Nelson',...  \
# 9      ['Michael Braff', 'Del Rey', 'Kristin Nelson',...
# 10     ['Tricia Narwani', 'Del Rey', 'Kristin Nelson'...
# 11     ['Tricia Narwani', 'Del Rey', 'Kristin Nelson'...
# 13     ['Tricia Narwani', 'Del Rey', 'Kristin Nelson'...
# ...                                                  ...
# 15785  ['Kelli Martin', 'Montlake Romance', 'Kevan Ly...
# 15786  ['Kelli Martin', 'Montlake Romance', 'Kevan Ly...
# 15789  ['Martin Biro', 'Lyrical Press', 'Jill Marsal'...
# 15795  ['Sharona Wilhelm', 'Scarsdale', 'Bob Diforio'...
# 15818  ['Emily Meehan', 'Disney-Hyperion', 'Diana Fox...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 8                                 NaN  175000.0         YES    YES        NaN  \
# 9                                 NaN  175000.0         YES    YES        NaN
# 10                                NaN  625000.0         NaN    NaN        YES
# 11                                NaN  175000.0         NaN    NaN        YES
# 13                                NaN  625000.0         NaN    NaN        YES
# ...                               ...       ...         ...    ...        ...
# 15785                             NaN   24500.5         NaN    NaN        NaN
# 15786                             NaN   24500.5         NaN    NaN        NaN
# 15789                             NaN   24500.5         NaN    NaN        NaN
# 15795                             NaN   24500.5         NaN    NaN        NaN
# 15818                             NaN  375000.0         YES    NaN        NaN
#
#       Self Publishing Debut Series
# 8                 NaN   NaN    NaN  \
# 9                 NaN   NaN    NaN
# 10                NaN   NaN    YES
# 11                NaN   NaN    NaN
# 13                NaN   NaN    YES
# ...               ...   ...    ...
# 15785             NaN   NaN    NaN
# 15786             NaN   NaN    NaN
# 15789             NaN   NaN    NaN
# 15795             NaN   NaN    NaN
# 15818             NaN   YES    NaN
#
#                                                      All  title_match_ratio
# 8      Bram Stoker Award-nominee Josh Malerman's UNBU...                 75
# 9      Bram Stoker Award-nominee Josh Malerman's UNBU...                 75
# 10     NYT-bestselling author of BIRD BOX Josh Malerm...                 59
# 11     NYT-bestselling author of BIRD BOX Josh Malerm...                 71
# 13     NYT-bestselling author of BIRD BOX Josh Malerm...                 48
# ...                                                  ...                ...
# 15785  Juliette Sobanet's MIDNIGHT TRAIN TO PARIS, th...                 55
# 15786  Juliette Sobanet's MIDNIGHT TRAIN TO PARIS, th...                 77
# 15789  Lynne Connolly's THE GIRL WITH THE PEARL PIN, ...                 43
# 15795  Anju Gattani's ONCE AND FOR ALL, DUTY AND DESI...                 60
# 15818  Cristin Terrill's debut ALL OUR YESTERDAYS, pi...                100
#
# [3557 rows x 20 columns]

# %%
for i in range(100):
    x = df_filtered[df_filtered['title_match_ratio'] >=i].shape[0]
    y = len(df_filtered['isbn13'].unique())
    if x==y:
        print(i)
        break

# %%
df_filtered[df_filtered['author'] =='Hilary Mantel']
# Out:
#          isbn13         author
# 1  9.780007e+12  Hilary Mantel  \
# 2  9.780008e+12  Hilary Mantel
# 3  9.781251e+12  Hilary Mantel
# 4  9.781251e+12  Hilary Mantel
# 5  9.781433e+12  Hilary Mantel
#
#                                                title datepublished
# 1                           The Mirror and the Light    2020-03-05  \
# 2  Mantel Pieces: The New Book from The Sunday Ti...    2020-10-06
# 3          Wolf Hall: A Novel (Wolf Hall Trilogy, 1)    2021-05-04
# 4  Bring Up the Bodies: A Novel (Wolf Hall Trilog...    2021-05-04
# 5  The Mirror & the Light (Thorndike Press Large ...    2020-04-15
#
#         Rights Category    Genre       Date      Author(s)
# 1  International rights  Fiction 2013-08-30  Hilary Mantel  \
# 2  International rights  Fiction 2013-08-30  Hilary Mantel
# 3  International rights  Fiction 2013-08-30  Hilary Mantel
# 4  International rights  Fiction 2013-08-30  Hilary Mantel
# 5  International rights  Fiction 2013-08-30  Hilary Mantel
#
#                        Title
# 1  A PLACE OF GREATER SAFETY  \
# 2  A PLACE OF GREATER SAFETY
# 3  A PLACE OF GREATER SAFETY
# 4  A PLACE OF GREATER SAFETY
# 5  A PLACE OF GREATER SAFETY
#
#                                           Publishers
# 1  ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  \
# 2  ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 3  ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 4  ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
# 5  ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...
#
#   Big Publishing House Affilation  Advance Competition Awards Bestseller
# 1                             NaN  24500.5         NaN    NaN        NaN  \
# 2                             NaN  24500.5         NaN    NaN        NaN
# 3                             NaN  24500.5         NaN    NaN        NaN
# 4                             NaN  24500.5         NaN    NaN        NaN
# 5                             NaN  24500.5         NaN    NaN        NaN
#
#   Self Publishing Debut Series
# 1             NaN   NaN    NaN  \
# 2             NaN   NaN    NaN
# 3             NaN   NaN    NaN
# 4             NaN   NaN    NaN
# 5             NaN   NaN    NaN
#
#                                                  All  title_match_ratio
# 1  Polish rights to Hilary Mantel's A PLACE OF GR...                 37
# 2  Polish rights to Hilary Mantel's A PLACE OF GR...                 29
# 3  Polish rights to Hilary Mantel's A PLACE OF GR...                 29
# 4  Polish rights to Hilary Mantel's A PLACE OF GR...                 25
# 5  Polish rights to Hilary Mantel's A PLACE OF GR...                 16

# %%
fuzz.token_sort_ratio('Unbury Carol (Thorndike Press Large Print Bill',"UNBURY CAROL")
# Out:
# 42

# %%
fuzz.token_sort_ratio('Unbury Carol (Thorndike Press Large Print Bill','BIRD BOX')
# Out:
# 15

# %%
full_merge = pd.merge(merged_book_adv, merged_sales_book, on=['isbn13','datepublished'])

# %%
print(len(full_merge['isbn13'].unique()), len(full_merge['author_y'].unique()))
# Out:
# 14118 3966

# %%
full_merge.shape
# Out:
# (28066, 24)

# %%
full_merge
# Out:
#              isbn13         author_x
# 0      9.780007e+12       Demi Moore  \
# 1      9.780007e+12    Hilary Mantel
# 2      9.780008e+12    Hilary Mantel
# 3      9.781251e+12    Hilary Mantel
# 4      9.781251e+12    Hilary Mantel
# ...             ...              ...
# 28061  9.798730e+12  Christy Barritt
# 28062  9.798730e+12  Christy Barritt
# 28063  9.798730e+12  Christy Barritt
# 28064  9.798734e+12      Yuri Elkaim
# 28065  9.798745e+12  Cristin Terrill
#
#                                                  title_x datepublished
# 0                                             Inside Out    2019-09-24  \
# 1                               The Mirror and the Light    2020-03-05
# 2      Mantel Pieces: The New Book from The Sunday Ti...    2020-10-06
# 3              Wolf Hall: A Novel (Wolf Hall Trilogy, 1)    2021-05-04
# 4      Bring Up the Bodies: A Novel (Wolf Hall Trilog...    2021-05-04
# ...                                                  ...           ...
# 28061  Rocco: a clean romantic suspense novel (Lanter...    2021-03-29
# 28062  Rocco: a clean romantic suspense novel (Lanter...    2021-03-29
# 28063  Rocco: a clean romantic suspense novel (Lanter...    2021-03-29
# 28064  The Strong60: Become The Person You're Capable...    2021-04-16
# 28065                                 All Our Yesterdays    2013-09-03
#
#             Rights Category                Genre       Date        Author(s)
# 0               Non-fiction               Memoir 2010-06-08       Demi Moore  \
# 1      International rights              Fiction 2013-08-30    Hilary Mantel
# 2      International rights              Fiction 2013-08-30    Hilary Mantel
# 3      International rights              Fiction 2013-08-30    Hilary Mantel
# 4      International rights              Fiction 2013-08-30    Hilary Mantel
# ...                     ...                  ...        ...              ...
# 28061               Fiction       Mystery/ Crime 2012-06-27  Christy Barritt
# 28062               Fiction              Romance 2010-10-07  Christy Barritt
# 28063               Fiction        Inspirational 2010-02-25  Christy Barritt
# 28064           Non-fiction                 Diet 2014-10-21      Yuri Elkaim
# 28065            Children's  Young Adult Fiction 2012-03-02  Cristin Terrill
#
#                                                    Title
# 0                                                   NONE  \
# 1                              A PLACE OF GREATER SAFETY
# 2                              A PLACE OF GREATER SAFETY
# 3                              A PLACE OF GREATER SAFETY
# 4                              A PLACE OF GREATER SAFETY
# ...                                                  ...
# 28061  ['KEY WITNESS', 'LETHAL JUSTICE', 'FINAL JUSTI...
# 28062                                    THE LAST TARGET
# 28063                                         UNDER FIRE
# 28064                                               NONE
# 28065                                 ALL OUR YESTERDAYS
#
#                                               Publishers  ... Self Publishing
# 0      ['Jonathan Burnham', 'Harper', 'Jennifer Barth...  ...             NaN  \
# 1      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  ...             NaN
# 2      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  ...             NaN
# 3      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  ...             NaN
# 4      ['Sonia Draga', 'Agata Zabowska', 'ANAW Litera...  ...             NaN
# ...                                                  ...  ...             ...
# 28061  ['Tina James', 'Love Inspired', 'Joyce Hart', ...  ...             NaN
# 28062  ['Tina James', 'Steeple Hill', 'Joyce Hart', '...  ...             NaN
# 28063  ['Tina James', 'Steeple Hill', 'Joyce Hart', '...  ...             NaN
# 28064  ['Jennifer Levesque', 'Rodale', 'Celeste Fine'...  ...             NaN
# 28065  ['Emily Meehan', 'Disney-Hyperion', 'Diana Fox...  ...             NaN
#
#        Debut Series                                                All
# 0        NaN    NaN  Demi Moore's currently untitled book, chronicl...  \
# 1        NaN    NaN  Polish rights to Hilary Mantel's A PLACE OF GR...
# 2        NaN    NaN  Polish rights to Hilary Mantel's A PLACE OF GR...
# 3        NaN    NaN  Polish rights to Hilary Mantel's A PLACE OF GR...
# 4        NaN    NaN  Polish rights to Hilary Mantel's A PLACE OF GR...
# ...      ...    ...                                                ...
# 28061    NaN    NaN  Christy Barritt's KEY WITNESS, when a woman st...
# 28062    NaN    NaN  Christy Barritt's THE LAST TARGET, in which a ...
# 28063    NaN    NaN  Christy Barritt's UNDER FIRE, as a woman's sta...
# 28064    NaN    YES  NYT bestselling author of The All-Day Energy D...
# 28065    YES    NaN  Cristin Terrill's debut ALL OUR YESTERDAYS, pi...
#
#       title_match_ratio totalrevenue totalunits        price         author_y
# 0                    29        27984         23  2234.078431       Demi Moore  \
# 1                    37      2996384       1125  2536.134694    Hilary Mantel
# 2                    29       636407        323  1910.756863    Hilary Mantel
# 3                    29        23200         16  1630.033333    Hilary Mantel
# 4                    25         6396          4  1659.767442    Hilary Mantel
# ...                 ...          ...        ...          ...              ...
# 28061                27        67548         52  1299.000000  Christy Barritt
# 28062                22        67548         52  1299.000000  Christy Barritt
# 28063                11        67548         52  1299.000000  Christy Barritt
# 28064                13         1895          1  1895.000000      Yuri Elkaim
# 28065               100            0          0  1299.000000  Cristin Terrill
#
#                                                  title_y
# 0                                             Inside Out
# 1                               The Mirror and the Light
# 2      Mantel Pieces: The New Book from The Sunday Ti...
# 3              Wolf Hall: A Novel (Wolf Hall Trilogy, 1)
# 4      Bring Up the Bodies: A Novel (Wolf Hall Trilog...
# ...                                                  ...
# 28061  Rocco: a clean romantic suspense novel (Lanter...
# 28062  Rocco: a clean romantic suspense novel (Lanter...
# 28063  Rocco: a clean romantic suspense novel (Lanter...
# 28064  The Strong60: Become The Person You're Capable...
# 28065                                 All Our Yesterdays
#
# [28066 rows x 25 columns]

# %%
full_merge_90_days = full_merge[(full_merge['datepublished'] - full_merge['Date']).dt.days >=90]

# %%
full_merge_90_days.to_csv('xxxx.csv')

# %%
temp = full_merge_90_days[['totalrevenue', 'Advance','datepublished','Date','author_x','isbn13']]

# %%
tempx =temp.groupby(['datepublished','Date','author_x','isbn13'], as_index=False).agg({'totalrevenue':'sum', 'Advance':'mean'})

# %%
tempx.to_csv('grouped_full_merged_printbook.csv')

# %%
len(tempx['isbn13'].unique())
# Out:
# 14118
