# %%
import pandas as pd
import spacy
import re
from fuzzywuzzy import fuzz
# Load the English language model in spaCy
nlp = spacy.load('en_core_web_sm')

# %%
def get_advances_data():
    
    adv = pd.read_excel('author_advance_dataset.xlsx', index_col=0)
    adv = adv[~adv['Advance'].isna()]
    deals = {
    'NICE' : (1+49000)/2,
    'VERY NICE' : (50000 + 99000)/2,
    'GOOD' : (100000 + 250000)/2,
    'SIGNIFICANT' : (251000 + 499000)/2,
    'MAJOR' : (500000 + 750000)/2
    }
    adv['Advance'] = adv['Advance'].replace(deals)

    adv.reset_index(inplace=True)
    adv.rename(columns={'index': 'advance_id'}, inplace=True) 
    return adv

def get_printbook_title_data():
    
    book = pd.read_csv('books/booktitle_printbooks_new.csv')
    book = book[['author','title','isbn13', 'datepublished']]
    book['datepublished']  = pd.to_datetime(book['datepublished'], errors = 'coerce')
    #book.rename(columns={'datepublished' : 'datepublished_booktitle_data'})
    
    #Get only the first published date for a given isbn13
    book = book.sort_values('datepublished')
    book = book.groupby('isbn13').first().reset_index()
    
    return book

def get_Ebook_title_data():
    
    book = pd.read_csv('books/booktitle_ebook_new.csv')
    book = book[['author','title','isbn13', 'datepublished']]
    book['datepublished']  = pd.to_datetime(book['datepublished'], errors = 'coerce')
    #book.rename(columns={'datepublished' : 'datepublished_booktitle_data'})
    
    #Get only the first published date for a given isbn13
    book = book.sort_values('datepublished')
    book = book.groupby('isbn13').first().reset_index()
    
    return book

def extract_author_name_1(text):
    doc = nlp(text)
    for entity in doc.ents:
        if entity.label_ == 'PERSON' and ("'s" in entity.text or "'" in entity.text):
            return entity.text
    return None


def extract_author_name_2(text):
    doc = nlp(text)
    for entity in doc.ents:
        if entity.label_ == 'PERSON' :#and ("'s" in entity.text or "'" in entity.text):
            return entity.text
    return None

def author_extraction(adv):
    adv['Author_extracted'] = adv['All'].apply(lambda x: extract_author_name_1(x))
    adv.loc[(adv['Author_extracted'].isna()) & ((adv['Author(s)'] == 'NONE') | (adv['Author(s)'] == 'All')), 'Author_extracted'] = adv.loc[(adv['Author_extracted'].isna()) & ((adv['Author(s)'] == 'NONE') | (adv['Author(s)'] == 'All')), 'All'].apply(lambda x: extract_author_name_2(x))
    adv.loc[(adv['Author_extracted'].isna()) & (adv['Author(s)'] != 'NONE'), 'Author_extracted'] = adv.loc[(adv['Author_extracted'].isna()) & (adv['Author(s)'] != 'NONE'), 'Author(s)'] 
    adv['Author_extracted'] = adv['Author_extracted'].str.replace("'s", "")
    adv['Author_extracted'] = adv['Author_extracted'].str.replace("'", "")
    adv['Author_extracted'] = adv['Author_extracted'].str.lower()
    return adv


def levenshtein_ratio(s1, s2):
    return fuzz.token_sort_ratio(s1, s2)

def get_GAPI_books():
    d1 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv.csv')
    d1['Author'] = d1['Author'].astype(str)
    d2 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv_17440.csv')
    d2['Author'] = d2['Author'].astype(str)
    d3 = pd.read_csv('AuthorCrosswalkScraper/Unmatched_extraction_of_authors.csv')
    d3['Author'] = d3['Author'].astype(str)
    d4 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv_x.csv')
    d4['Author'] = d4['Author'].astype(str)
    d = pd.concat([d1,d2],axis=0)
    d = pd.concat([d,d3], axis=0)
    d = pd.concat([d,d4], axis=0)
    d['Author'] = d['Author'].astype(str)
    d['Author'] = d['Author'].str.replace("[","")
    d['Author'] = d['Author'].str.replace("]","")
    d['Author'] = d['Author'].str.replace("'","")
    d['author_l'] = d['Author'].str.lower()
    d = d.drop(columns='Unnamed: 0')
    d.columns = ['author','title','datepublished','isbn13','author_l']
    
    return d

def merge_book_advances(book, adv):
    
    book_adv = pd.merge(book, adv, left_on='author_l', right_on='Author_extracted')
    book_adv['fuzz_ratio'] = book_adv.apply(lambda x : levenshtein_ratio(str(x['Title']).lower(), str(x['title']).lower()), axis=1)
    
    extract_all_caps = lambda text: ' '.join(re.findall(r'\b[A-Z]{2,}\b', text))
    book_adv['title_extracted'] = book_adv['All'].apply(extract_all_caps)
    
    book_adv = book_adv[~((book_adv['Title'] == 'NONE') & (book_adv['title_extracted']=="")) ]
    book_adv.loc[book_adv['Title'] == 'NONE', 'fuzz_ratio'] = book_adv.loc[book_adv['Title'] == 'NONE'].apply(lambda x : levenshtein_ratio(str(x['title_extracted']).lower(), str(x['title']).lower()), axis=1)
    
    book_adv['datepublished'] = book_adv['datepublished'].astype(str)
    book_adv['datepublished'] = pd.to_datetime(book_adv['datepublished'], errors='coerce')
    book_adv['datepublished'] = book_adv['datepublished'].apply(lambda x: x.date() if pd.notnull(x) and hasattr(x, 'date') else pd.NaT if pd.isnull(x) else pd.to_datetime(x[:10]).date() if len(x) == 10 else pd.to_datetime(x + '-12-31').date() if len(x) == 4 else pd.to_datetime(x + '-01').date() + pd.offsets.MonthEnd() if len(x) == 7 else x)
    '''
    book_adv_grouped = book_adv.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
    book_adv_grouped = book_adv_grouped.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
    '''
    book_adv_grouped = book_adv
    book_adv_grouped['datepublished'] = pd.to_datetime(book_adv_grouped['datepublished'])
    return book_adv_grouped

# %%
adv = get_advances_data()

# %%
adv = author_extraction(adv)

# %%
print(adv.shape, adv['advance_id'].unique().shape, adv['Author_extracted'].unique().shape)
# Out:
# (34297, 17) (34297,) (22843,)

# %%
d = get_GAPI_books()

# %%
d.columns
# Out:
# Index(['author', 'title', 'datepublished', 'isbn13', 'author_l'], dtype='object')

# %%
print(d.shape, d['author_l'].unique().shape, d['isbn13'].unique().shape)
# Out:
# (305952, 5) (139705,) (289390,)

# %%
merg = merge_book_advances(d, adv)

# %%
merg.columns
# Out:
# Index(['author', 'title', 'datepublished', 'isbn13', 'author_l', 'advance_id',
#        'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All',
#        'Author_extracted', 'fuzz_ratio', 'title_extracted'],
#       dtype='object')

# %%
print(merg.shape, merg['advance_id'].unique().shape, merg['isbn13'].unique().shape, merg['author_l'].unique().shape)
# Out:
# (251464, 24) (22419,) (120868,) (14198,)

# %%
f = merg[merg['fuzz_ratio']>=95]
f = f.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
f = f.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
print(f.shape, f['advance_id'].unique().shape, f['isbn13'].unique().shape, f['author_l'].unique().shape)
# Out:
# (8217, 24) (8217,) (8217,) (7213,)

# %%
f
# Out:
#                   author                          title datepublished
# 0     Susan Arnout Smith                 The Timer Game    2008-01-01  \
# 1             Bel Mooney  Small Dogs Can Save Your Life    2010-01-01
# 2           Philip Mould                         Sleuth    2011-01-01
# 3           Janice Hardy             The Pain Merchants    2010-01-01
# 4            Ellen Horan                 31 Bond Street    2010-01-01
# ...                  ...                            ...           ...
# 8212         John Coates          The Problem of Twelve           NaT
# 8213    Ganesh Sitaraman        Why Flying Is Miserable    2023-01-01
# 8214            Rain Nox                 Animal Charmer           NaT
# 8215        Jane Anthony                P.S. I Hate You           NaT
# 8216      Julie McElwain                Ripples in Time    2023-01-01
#
#              isbn13            author_l  advance_id       Rights Category
# 0     9780007265176  susan arnout smith      127148               Fiction  \
# 1     9780007318704          bel mooney      163069  International rights
# 2     9780007319152        philip mould      158567           Non-fiction
# 3     9780007326792        janice hardy      165232            Children's
# 4     9780007353040         ellen horan      164724               Fiction
# ...             ...                 ...         ...                   ...
# 8212  9798987053546         john coates         150           Non-fiction
# 8213  9798987053584    ganesh sitaraman         149           Non-fiction
# 8214  9798987208359            rain nox       13637       Digital Fiction
# 8215  9798987262108        jane anthony        2668  International rights
# 8216  9798987381038      julie mcelwain         995          Audio rights
#
#                              Genre       Date           Author(s)  ...
# 0                   Mystery/ Crime 2012-12-11  Susan Arnout Smith  ...  \
# 1                   UK Non-fiction 2008-10-23          Bel Mooney  ...
# 2                       True crime 2009-05-29        Philip Mould  ...
# 3                          Fantasy 2008-06-26        Janice Hardy  ...
# 4                            Debut 2008-07-28         Ellen Horan  ...
# ...                            ...        ...                 ...  ...
# 8212  Business/ Finance/ Economics 2023-03-10         John Coates  ...
# 8213  Business/ Finance/ Economics 2023-03-10    Ganesh Sitaraman  ...
# 8214                       Romance 2022-03-24            Rain Nox  ...
# 8215                       Fiction 2023-01-12                NONE  ...
# 8216                          NONE 2023-02-21      Julie McElwain  ...
#
#      Competition Awards Bestseller  Self Publishing Debut Series
# 0            NaN    NaN        NaN              NaN   NaN    NaN  \
# 1            YES    NaN        NaN              NaN   NaN    NaN
# 2            YES    NaN        NaN              NaN   NaN    NaN
# 3            YES    NaN        NaN              NaN   YES    NaN
# 4            YES    NaN        NaN              NaN   NaN    NaN
# ...          ...    ...        ...              ...   ...    ...
# 8212         NaN    NaN        NaN              NaN   NaN    NaN
# 8213         NaN    NaN        NaN              NaN   NaN    NaN
# 8214         NaN    NaN        NaN              NaN   YES    NaN
# 8215         NaN    NaN        NaN              NaN   NaN    NaN
# 8216         NaN    NaN        NaN              NaN   NaN    NaN
#
#                                                     All    Author_extracted
# 0     Susan Arnout Smith's THE TIMER GAME, after giv...  susan arnout smith  \
# 1     Daily Mail advice columnist Bel Mooney's SMALL...          bel mooney
# 2     International art dealer and BBC Antiques Road...        philip mould
# 3     Janice Hardy's debut fantasy trilogy beginning...        janice hardy
# 4     Ellen Horan's 31 BOND STREET, interweaving fic...         ellen horan
# ...                                                 ...                 ...
# 8212  Professor of law and economics at Harvard Law ...         john coates
# 8213  Law professor at Vanderbilt Law School and aut...    ganesh sitaraman
# 8214  Fronterafest Best of Fest playwright Rain Nox'...            rain nox
# 8215  Jane Anthony's P.S. I HATE YOU, to Queen (Ital...        jane anthony
# 8216  Julie McElwain's RIPPLES IN TIME, the sixth bo...      julie mcelwain
#
#      fuzz_ratio                                    title_extracted
# 0           100                                  THE TIMER GAME US
# 1           100                SMALL DOGS CAN SAVE YOUR LIFE UK US
# 2           100                                      BBC SLEUTH UK
# 3           100                                 THE PAIN MERCHANTS
# 4           100                                        BOND STREET
# ...         ...                                                ...
# 8212        100  THE PROBLEM OF TWELVE WHEN FEW FINANCIAL INSTI...
# 8213        100  THE CRISIS OF THE MIDDLE CLASS CONSTITUTION TH...
# 8214        100     ANIMAL CHARMER THE GOOD WITCH DOCTOR DOOLITTLE
# 8215        100                                       HATE YOU SBR
# 8216        100                                    RIPPLES IN TIME
#
# [8217 rows x 24 columns]

# %%
filtered_merg = merg[((merg['datepublished'] - merg['Date']).dt.days <=1460) & ((merg['datepublished'] - merg['Date']).dt.days >=90) & (merg['fuzz_ratio']>=80)]
filtered_merg = filtered_merg.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
filtered_merg = filtered_merg.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
print(filtered_merg.shape, filtered_merg['advance_id'].unique().shape, filtered_merg['isbn13'].unique().shape, filtered_merg['author_l'].unique().shape)
# Out:
# (5202, 24) (5202,) (5202,) (4642,)

# %%
df = pd.concat([f,filtered_merg], axis=0)
df = df.drop_duplicates()
df = df.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
df = df.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
print(df.shape, df['advance_id'].unique().shape, df['isbn13'].unique().shape, df['author_l'].unique().shape)
# Out:
# (8730, 24) (8730,) (8730,) (7576,)

# %%
rem = merg[(~merg['isbn13'].isin(df['isbn13'])) & (~merg['advance_id'].isin(df['advance_id']))]

# %%
rem
# Out:
#              author                       title datepublished         isbn13
# 0       Terry Spear     The Best of Both Wolves    2022-01-01  9781728228822  \
# 1       Terry Spear               Savage Hunger    2012-01-01  9781402266935
# 2       Terry Spear           Heart of the Wolf    2008-01-01  9781402233852
# 3       Terry Spear               Highland Rake    2012-01-01  9781480259034
# 4       Terry Spear   Terry Spear’s Wolf Bundle    2010-01-01  9781402262401
# ...             ...                         ...           ...            ...
# 265863    L. Divine  Drama High: Keep It Movin'    2009-01-01  9780758231079
# 265864    L. Divine       Drama High: The Fight    2006-01-01  9780758216342
# 265865    L. Divine             Drama High, V19    2020-01-01  9780985736859
# 265866    L. Divine                    No Mercy    2013-01-01  9780985736811
# 265867    L. Divine   Drama High: Culture Clash    2010-01-01  9780758256812
#
#            author_l  advance_id Rights Category                Genre
# 0       terry spear      128632         Fiction              Romance  \
# 1       terry spear      128632         Fiction              Romance
# 2       terry spear      128632         Fiction              Romance
# 3       terry spear      128632         Fiction              Romance
# 4       terry spear      128632         Fiction              Romance
# ...             ...         ...             ...                  ...
# 265863    l. divine      168472      Children's  Young Adult Fiction
# 265864    l. divine      168472      Children's  Young Adult Fiction
# 265865    l. divine      168472      Children's  Young Adult Fiction
# 265866    l. divine      168472      Children's  Young Adult Fiction
# 265867    l. divine      168472      Children's  Young Adult Fiction
#
#              Date    Author(s)  ... Competition Awards Bestseller
# 0      2012-10-15  Terry Spear  ...         NaN    NaN        NaN  \
# 1      2012-10-15  Terry Spear  ...         NaN    NaN        NaN
# 2      2012-10-15  Terry Spear  ...         NaN    NaN        NaN
# 3      2012-10-15  Terry Spear  ...         NaN    NaN        NaN
# 4      2012-10-15  Terry Spear  ...         NaN    NaN        NaN
# ...           ...          ...  ...         ...    ...        ...
# 265863 2008-01-21    L. Divine  ...         NaN    NaN        NaN
# 265864 2008-01-21    L. Divine  ...         NaN    NaN        NaN
# 265865 2008-01-21    L. Divine  ...         NaN    NaN        NaN
# 265866 2008-01-21    L. Divine  ...         NaN    NaN        NaN
# 265867 2008-01-21    L. Divine  ...         NaN    NaN        NaN
#
#         Self Publishing Debut Series
# 0                   NaN   NaN    NaN  \
# 1                   NaN   NaN    NaN
# 2                   NaN   NaN    NaN
# 3                   NaN   NaN    NaN
# 4                   NaN   NaN    NaN
# ...                 ...   ...    ...
# 265863              NaN   NaN    NaN
# 265864              NaN   NaN    NaN
# 265865              NaN   NaN    NaN
# 265866              NaN   NaN    NaN
# 265867              NaN   NaN    NaN
#
#                                                       All Author_extracted
# 0       Terry Spear's A SEAL WOLF CHRISTMAS, about a c...      terry spear  \
# 1       Terry Spear's A SEAL WOLF CHRISTMAS, about a c...      terry spear
# 2       Terry Spear's A SEAL WOLF CHRISTMAS, about a c...      terry spear
# 3       Terry Spear's A SEAL WOLF CHRISTMAS, about a c...      terry spear
# 4       Terry Spear's A SEAL WOLF CHRISTMAS, about a c...      terry spear
# ...                                                   ...              ...
# 265863  L. Divine's DRAMA HIGH, the next eight books i...        l. divine
# 265864  L. Divine's DRAMA HIGH, the next eight books i...        l. divine
# 265865  L. Divine's DRAMA HIGH, the next eight books i...        l. divine
# 265866  L. Divine's DRAMA HIGH, the next eight books i...        l. divine
# 265867  L. Divine's DRAMA HIGH, the next eight books i...        l. divine
#
#        fuzz_ratio      title_extracted
# 0              36  SEAL WOLF CHRISTMAS
# 1              29  SEAL WOLF CHRISTMAS
# 2              53  SEAL WOLF CHRISTMAS
# 3              29  SEAL WOLF CHRISTMAS
# 4              48  SEAL WOLF CHRISTMAS
# ...           ...                  ...
# 265863         59           DRAMA HIGH
# 265864         67           DRAMA HIGH
# 265865         83           DRAMA HIGH
# 265866         22           DRAMA HIGH
# 265867         59           DRAMA HIGH
#
# [145114 rows x 24 columns]

# %%
rem = d[~d['isbn13'].isin(df['isbn13'])]

# %%
counts = rem['author_l'].value_counts()
remx = rem[rem['author_l'].map(counts) == 1]

# %%
remx

# %%
remx
# Out:
#                                                   author
# 47                                     Courtney A. Short  \
# 395     Tammy Donham, Amy Sue Macy, Clyde Philip Rolston
# 396           John Caldwell Calhoun, Clyde Norman Wilson
# 398                                Clyde R. Forsberg Jr.
# 399                                 Clyde W. Franklin II
# ...                                                  ...
# 29972                                     Debra M Amidon
# 29973                          Debra Hickenlooper Sowell
# 29974                                       Debra Monroe
# 29975  Andrew R. Hoehn, Richard H. Solomon, Sonni Efr...
# 29978                   Jane King Hession, Debra Pickrel
#
#                                          title datepublished         isbn13
# 47                           Uniquely Okinawan          2020  9780823288403  \
# 395                   Marketing Recorded Music          2022  9781000585148
# 396              The Papers of John C. Calhoun          1959  9780872494831
# 398                       Divine Rite of Kings          2016  9781443889575
# 399     The Changing Definition of Masculinity          2012  9781461327219
# ...                                        ...           ...            ...
# 29972              The Innovation SuperHighway          2007  9781136357343
# 29973                     Christensen Brothers          2014  9781134422548
# 29974               On the Outskirts of Normal          2015  9780820349114
# 29975  Strategic Choices for a Turbulent World          2017  9780833096937
# 29978           Frank Lloyd Wright in New York          2007  9781423601012
#
#                                                 author_l
# 47                                     courtney a. short
# 395     tammy donham, amy sue macy, clyde philip rolston
# 396           john caldwell calhoun, clyde norman wilson
# 398                                clyde r. forsberg jr.
# 399                                 clyde w. franklin ii
# ...                                                  ...
# 29972                                     debra m amidon
# 29973                          debra hickenlooper sowell
# 29974                                       debra monroe
# 29975  andrew r. hoehn, richard h. solomon, sonni efr...
# 29978                   jane king hession, debra pickrel
#
# [104782 rows x 5 columns]

# %%
remx = remx[((remx['datepublished'] - remx['Date']).dt.days <=1460) & ((remx['datepublished'] - remx['Date']).dt.days >=90) & (remx['author_l'].isin(df['author_l']))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3651         try:
# -> 3652             return self._engine.get_loc(casted_key)
#    3653         except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-340f16e84866> in <module>
# ----> 1 remx = remx[((remx['datepublished'] - remx['Date']).dt.days <=1460) & ((remx['datepublished'] - remx['Date']).dt.days >=90) & (remx['author_l'].isin(df['author_l']))]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652             return self._engine.get_loc(casted_key)
#    3653         except KeyError as err:
# -> 3654             raise KeyError(key) from err
#    3655         except TypeError:
#    3656             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
print(remx.shape, remx['advance_id'].unique().shape, remx['isbn13'].unique().shape, remx['author_l'].unique().shape)
# Out:
# (0, 24) (0,) (0,) (0,)

# %%
final = pd.concat([df, remx], axis = 0)
final = final.drop_duplicates()
final = final.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
final = final.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
final.columns
# Out:
# Index(['author', 'title', 'datepublished', 'isbn13', 'author_l', 'advance_id',
#        'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All',
#        'Author_extracted', 'fuzz_ratio', 'title_extracted'],
#       dtype='object')

# %%
print(final.shape, final['advance_id'].unique().shape, final['isbn13'].unique().shape, final['author_l'].unique().shape)
# Out:
# (8730, 24) (8730,) (8730,) (7576,)

# %%
df.to_csv('true_merge.csv')

# %%
#step 1
d = get_GAPI_books()
#step 2
adv = get_advances_data()
adv = author_extraction(adv)
#step 3
merg = merge_book_advances(d, adv)
#step 4
f = merg[merg['fuzz_ratio']>=95]
f = f.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
f = f.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
#step 5
filtered_merg = merg[((merg['datepublished'] - merg['Date']).dt.days <=1460) & ((merg['datepublished'] - merg['Date']).dt.days >=90) & (merg['fuzz_ratio']>=80)]
filtered_merg = filtered_merg.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
filtered_merg = filtered_merg.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

#step 6
df = pd.concat([f,filtered_merg], axis=0)
df = df.drop_duplicates()
df = df.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
df = df.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

#step 7
rem = merg[(~merg['isbn13'].isin(df['isbn13'])) & (~merg['advance_id'].isin(df['advance_id']))]
rem = merg[((merg['datepublished'] - merg['Date']).dt.days <=1460) & ((merg['datepublished'] - merg['Date']).dt.days >=90)]
df = pd.concat([df,rem], axis=0)
df = df.drop_duplicates()
df = df.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
df = df.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
print(df.shape, df['advance_id'].unique().shape, df['isbn13'].unique().shape, df['author_l'].unique().shape)
# Out:
# (15308, 24) (15308,) (15308,) (11810,)

# %%
adv[~adv['Author_extracted'].isin(d['author_l'])]
# Out:
#        advance_id Rights Category                 Genre       Date
# 2               7         Fiction                Horror 2023-03-15  \
# 3              13      Children's  Picture Book Fiction 2023-03-15
# 4              22      Children's         Graphic Novel 2023-03-14
# 5              42     Non-fiction        Food/ Beverage 2023-03-14
# 10             56         Fiction                 Debut 2023-03-14
# ...           ...             ...                   ...        ...
# 34289      168745         Fiction         Inspirational 2008-01-08
# 34291      168759         Fiction               Romance 2008-01-07
# 34292      168767     Non-fiction               History 2008-01-07
# 34295      168797     Non-fiction                How-To 2008-01-04
# 34296      168799     Non-fiction                Memoir 2008-01-04
#
#                                    Author(s)                        Title
# 2                             Chance Forshee  A TERRIFYING TOME OF TERROR  \
# 3            ['Debra Buschman', 'Tom Uleau']      THE KNIGHT & HIS TRUSTY
# 4                                  Junepurrr                      SUBZERO
# 5                               Sarah Thrush  PRESERVATION WITH A PURPOSE
# 10                               Carinn Jade          THE ASTROLOGY HOUSE
# ...                                      ...                          ...
# 34289                       Kathleen Y'Barbo          THE BELOVED CAPTIVE
# 34291                     Cindy Procter-King          KISS ME AT MIDNIGHT
# 34292                            Stefan Aust               BAADER-MEINHOF
# 34295        ['Linda Meyers', 'John Meyers']               TOSSED & FOUND
# 34296  ["Chris O'Dell", 'Katherine Ketcham']              LADY IN WAITING
#
#                                               Publishers
# 2         ['Jennifer Barnes', 'Raw Dog Screaming Press']  \
# 3                 ['Michele McAvoy', 'The Little Press']
# 4      ['Desiree Rodriguez', 'Oni Press', 'Britt Sies...
# 5      ['Dan Rosenberg', 'Harvard Common Press', 'Jan...
# 10     ['Natalie Hallak', 'Atria', 'Claire Friedman',...
# ...                                                  ...
# 34289  ['Rebecca Germany', 'Barbour', 'Wendy Lawton',...
# 34291                    ['Theresa Stevens', 'Red Sage']
# 34292          ['Cybele Tom', 'Oxford University Press']
# 34295  ['Dervla Kelly', 'Stewart, Tabori & Chang', 'S...
# 34296  ['Trish Todd', 'Touchstone Fireside', 'Linda L...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 2                                 NaN   24500.5         NaN    NaN        NaN  \
# 3                                 NaN   24500.5         NaN    NaN        NaN
# 4                                 NaN   74500.0         NaN    NaN        NaN
# 5                                 NaN   24500.5         YES    NaN        NaN
# 10                                NaN  375000.0         YES    NaN        NaN
# ...                               ...       ...         ...    ...        ...
# 34289                             NaN   24500.5         NaN    NaN        NaN
# 34291                             NaN   24500.5         NaN    NaN        NaN
# 34292                             NaN   24500.5         NaN    NaN        NaN
# 34295                             NaN   24500.5         NaN    NaN        NaN
# 34296                             NaN  375000.0         YES    NaN        NaN
#
#       Self Publishing Debut Series
# 2                 NaN   NaN    NaN  \
# 3                 NaN   NaN    NaN
# 4                 NaN   NaN    NaN
# 5                 NaN   NaN    NaN
# 10                NaN   NaN    NaN
# ...               ...   ...    ...
# 34289             NaN   NaN    NaN
# 34291             NaN   NaN    NaN
# 34292             NaN   NaN    NaN
# 34295             NaN   NaN    NaN
# 34296             NaN   NaN    NaN
#
#                                                      All
# 2      The Curator of Horror, a bookseller, and host ...  \
# 3      SCBWI Wisconsin Regional Advisor Debra Buschma...
# 4      Creator of the webcomic series of the same nam...
# 5      Homesteading economist, teacher, and naturalis...
# 10     Pop Fiction Women podcast host Carinn Jade's T...
# ...                                                  ...
# 34289  Kathleen Y'Barbo's THE BELOVED CAPTIVE, to Reb...
# 34291  Cindy Procter-King writing as Kate St. James's...
# 34292  Der Spiegel's Editor-in-Chief Stefan Aust's BA...
# 34295  Interior designers Linda Meyers and John Meyer...
# 34296  Tour manager, friend, lover, and confidante to...
#
#                   Author_extracted
# 2                   chance forshee
# 3      [debra buschman, tom uleau]
# 4                        junepurrr
# 5                     sarah thrush
# 10                     carinn jade
# ...                            ...
# 34289              kathleen ybarbo
# 34291               kate st. james
# 34292                  der spiegel
# 34295                  john meyers
# 34296                  chris odell
#
# [10933 rows x 17 columns]

# %%
adv_eth = author_ethnicity(adv)

# %%
adv_eth['Date'] = pd.to_datetime(adv_eth['Date']).dt.strftime('%Y-%m')
adv_eth['Date'] = pd.to_datetime(adv_eth['Date'])

# %%
adv_eth
# Out:
#        advance_id       Rights Category                         Genre
# 0               2  International rights                    UK Fiction  \
# 1               7               Fiction                        Horror
# 2               4  International rights                       Fiction
# 3              64  International rights                       Fiction
# 4              52  International rights                       Fiction
# ...           ...                   ...                           ...
# 31912      168736           Non-fiction  Business/ Finance/ Economics
# 31913      168732           Non-fiction                         Humor
# 31914      168725           Non-fiction                     Reference
# 31915      168759               Fiction                       Romance
# 31916      168767           Non-fiction                       History
#
#             Date                Author(s)
# 0     2023-03-01  Kynpham Sing Nongkynrih  \
# 1     2023-03-01           Chance Forshee
# 2     2023-03-01                     NONE
# 3     2023-03-01                     NONE
# 4     2023-03-01                     NONE
# ...          ...                      ...
# 31912 2008-01-01           Stephen Lundin
# 31913 2008-01-01           Sharon Nichols
# 31914 2008-01-01               Sage Cohen
# 31915 2008-01-01       Cindy Procter-King
# 31916 2008-01-01              Stefan Aust
#
#                                        Title
# 0                             FUNERAL NIGHTS  \
# 1                A TERRIFYING TOME OF TERROR
# 2                         THE SHADOW MURDERS
# 3                               IFOLGE LOVEN
# 4                                       NONE
# ...                                      ...
# 31912                                  CATS!
# 31913  I JUDGE YOU WHEN YOU USE POOR GRAMMAR
# 31914            THE WRITING THE LIFE POETIC
# 31915                    KISS ME AT MIDNIGHT
# 31916                         BAADER-MEINHOF
#
#                                               Publishers
# 0      ['Stefan Tobler', 'And Other Stories', 'Tara T...  \
# 1         ['Jennifer Barnes', 'Raw Dog Screaming Press']
# 2      ['Fantasy Foundation', 'Ann Huang', 'The Grayh...
# 3      ['Matthes & Seitz', 'Sophia Hersi Smith', 'Cop...
# 4      ['AST', 'Konstantin Palchikov', 'Sergei Chered...
# ...                                                  ...
# 31912                  ['Herb Schaffner', 'McGraw-Hill']
# 31913  ['Daniela Rapp', 'Griffin', 'Neil Salkind', 'S...
# 31914  ['Jane Friedman', "Writer's Digest Books", 'Ma...
# 31915                    ['Theresa Stevens', 'Red Sage']
# 31916          ['Cybele Tom', 'Oxford University Press']
#
#       Big Publishing House Affilation  Advance Competition  ... Series
# 0                                 NaN  24500.5         NaN  ...    NaN  \
# 1                                 NaN  24500.5         NaN  ...    NaN
# 2                                 NaN  24500.5         NaN  ...    NaN
# 3                                 NaN  24500.5         NaN  ...    NaN
# 4                                 NaN  24500.5         NaN  ...    NaN
# ...                               ...      ...         ...  ...    ...
# 31912                             NaN  74500.0         NaN  ...    NaN
# 31913                             NaN  24500.5         NaN  ...    NaN
# 31914                             NaN  24500.5         NaN  ...    NaN
# 31915                             NaN  24500.5         NaN  ...    NaN
# 31916                             NaN  24500.5         NaN  ...    NaN
#
#                                                      All
# 0      Indian writer Kynpham Sing Nongkynrih's FUNERA...  \
# 1      The Curator of Horror, a bookseller, and host ...
# 2      Jussi Adler-Olsen's THE SHADOW MURDERS, to Fan...
# 3      Solvej Balle's IFOLGE LOVEN, to Matthes & Seit...
# 4      Lois McMaster Bujold's World of the Five Gods ...
# ...                                                  ...
# 31912  FISH! author Stephen Lundin's CATS!: The Nine ...
# 31913  Sharon Nichols's I JUDGE YOU WHEN YOU USE POOR...
# 31914  Sage Cohen's THE WRITING THE LIFE POETIC, an e...
# 31915  Cindy Procter-King writing as Kate St. James's...
# 31916  Der Spiegel's Editor-in-Chief Stefan Aust's BA...
#
#               Author_extracted First Name     Last Name     asian  hispanic
# 0      kynpham sing nongkynrih    Kynpham    Nongkynrih  0.048560  0.014498  \
# 1               chance forshee     Chance       Forshee  0.002367  0.005476
# 2            jussi adler-olsen       NONE          NONE  0.003922  0.014060
# 3                        balle       NONE          NONE  0.003922  0.014060
# 4         lois mcmaster bujold       NONE          NONE  0.003922  0.014060
# ...                        ...        ...           ...       ...       ...
# 31912           stephen lundin    Stephen        Lundin  0.005477  0.026408
# 31913           sharon nichols     Sharon       Nichols  0.000906  0.005719
# 31914               sage cohen       Sage         Cohen  0.023355  0.045515
# 31915           kate st. james      Cindy  Procter-King  0.005292  0.018177
# 31916              der spiegel     Stefan          Aust  0.004299  0.019221
#
#        nh_black  nh_white      race
# 0      0.018025  0.918917  nh_white
# 1      0.105410  0.886747  nh_white
# 2      0.121864  0.860154  nh_white
# 3      0.121864  0.860154  nh_white
# 4      0.121864  0.860154  nh_white
# ...         ...       ...       ...
# 31912  0.040033  0.928082  nh_white
# 31913  0.127225  0.866150  nh_white
# 31914  0.142626  0.788503  nh_white
# 31915  0.047628  0.928903  nh_white
# 31916  0.056045  0.920435  nh_white
#
# [31917 rows x 24 columns]

# %%
adv_eth.groupby('Date',as_index=False).agg({'Advance':'sum'})
# Out:
#           Date     Advance
# 0   2008-01-01  14767049.0
# 1   2008-02-01  17042550.0
# 2   2008-03-01  13743552.5
# 3   2008-04-01  23750540.5
# 4   2008-05-01  16384054.0
# ..         ...         ...
# 178 2022-11-01  18706584.0
# 179 2022-12-01  16285584.0
# 180 2023-01-01  18388602.0
# 181 2023-02-01  18559107.5
# 182 2023-03-01   8568552.5
#
# [183 rows x 2 columns]

# %%
adv_eth.to_csv('advances_with_ethnicity.csv')

# %%
import gender_guesser.detector as gender

d = gender.Detector(case_sensitive=False)
f1['gender'] = f1['First Name'].apply(lambda x : d.get_gender(x))

# %%
f1.to_csv('sales_adv_book_title_merge.csv')

# %%
sales['datepublished'] = pd.to_datetime(sales['datepublished']).dt.strftime('%Y-%m')

# %%
sales = sales.groupby(['isbn13','datepublished'], as_index=False).agg({'totalrevenue':'sum', 'totalunits':'sum', 'price':'mean'})

# %%
sales['datepublished'] = pd.to_datetime(sales['datepublished'])

# %%
sales.to_csv('sales_data.csv')

# %%
salx = sales.groupby(['datepublished'], as_index=False).agg({'totalrevenue':'sum', 'totalunits':'sum', 'price':'mean'})

# %%
salx[(salx['datepublished']>='2000') & (salx['datepublished']<='2024')].to_csv('sales_by_month.csv')

# %%
adv['All'][0]
# Out:
# "Indian writer Kynpham Sing Nongkynrih's FUNERAL NIGHTS, an epic novel about the Khasi people of Northeast India, combining folklore, culture and history, and life and death, pitched as the 'Moby Dick of Meghalaya' and about a group of friends witnessing a unique and ancient six-day-long funeral ceremony, the last of its kind, to Stefan Tobler at And Other Stories, with Tara Tobler editing, in a nice deal, for publication in 2024, by Kanishka Gupta at Writer's Side (world ex South Asia)."

# %%
test3_1 = test3[~test3.isin(x)]

# %%
test3_1[test3_1['fuzz_ratio']>=90]
# Out:
#         advance_id       Rights Category            Genre       Date
# 9              4.0  International rights          Fiction 2023-03-15  \
# 13         42782.0  International rights          Fiction 2020-02-18
# 60         84323.0               Fiction   General/ Other 2016-10-25
# 181       137522.0               Fiction  Sci-Fi/ Fantasy 2011-11-20
# 188           47.0               Fiction   General/ Other 2023-03-14
# ...            ...                   ...              ...        ...
# 325038    168622.0           Non-fiction           Memoir 2008-01-13
# 325039    168622.0           Non-fiction           Memoir 2008-01-13
# 325040    168635.0  International rights   UK Non-fiction 2008-01-11
# 325047    168703.0               Fiction   General/ Other 2008-01-09
# 325083    168725.0           Non-fiction        Reference 2008-01-08
#
#                    Author(s)
# 9                       NONE  \
# 13                      NONE
# 60             Leigh Bardugo
# 181     Lois McMaster Bujold
# 188           Paolo Giordano
# ...                      ...
# 325038          Lynn Reardon
# 325039          Lynn Reardon
# 325040      Bill Giovannetti
# 325047   Mary McGarry Morris
# 325083            Sage Cohen
#
#                                                     Title
# 9                                      THE SHADOW MURDERS  \
# 13                                            VICTIM 2117
# 60                                            NINTH HOUSE
# 181                          CAPTAIN VORPATRIL'S ALLIANCE
# 188                                              TASMANIA
# ...                                                   ...
# 325038                             BEYOND THE HOMESTRETCH
# 325039                             BEYOND THE HOMESTRETCH
# 325040  HOW TO KEEP YOUR INNER MESS FROM TRASHING YOUR...
# 325047                                    THE LAST SECRET
# 325083                        THE WRITING THE LIFE POETIC
#
#                                                Publishers
# 9       ['Fantasy Foundation', 'Ann Huang', 'The Grayh...  \
# 13      ['Fantasy Foundation', 'Ping Chang', 'The Gray...
# 60      ['Noah Eaker', 'Flatiron Books', 'Joanna Volpe...
# 181     ['Toni Weisskopf', 'Baen Books', 'Eleanor Wood...
# 188     ['Judith Gurewich', 'Other Press', 'Marleen Se...
# ...                                                   ...
# 325038  ['Jason Gardner', 'New World Library', 'Elise ...
# 325039  ['Jason Gardner', 'New World Library', 'Elise ...
# 325040  ['Tony Collins', 'Lion Hudson Books', 'Janet K...
# 325047  ['John Glusman', 'Shaye Areheart Books', 'Jean...
# 325083  ['Jane Friedman', "Writer's Digest Books", 'Ma...
#
#        Big Publishing House Affilation   Advance Competition  ... Series
# 9                                  NaN   24500.5         NaN  ...    NaN  \
# 13                                 NaN   24500.5         NaN  ...    NaN
# 60                                 NaN  625000.0         NaN  ...    NaN
# 181                                NaN  175000.0         NaN  ...    NaN
# 188                                NaN   24500.5         NaN  ...    NaN
# ...                                ...       ...         ...  ...    ...
# 325038                             NaN   24500.5         NaN  ...    NaN
# 325039                             NaN   24500.5         NaN  ...    NaN
# 325040                             NaN   24500.5         NaN  ...    NaN
# 325047                             NaN  625000.0         NaN  ...    NaN
# 325083                             NaN   24500.5         NaN  ...    NaN
#
#                                                       All
# 9       Jussi Adler-Olsen's THE SHADOW MURDERS, to Fan...  \
# 13      Jussi Adler-Olsen's VICTIM 2117, to Fantasy Fo...
# 60      NYT bestselling author of SIX OF CROWS and CRO...
# 181     Lois McMaster Bujold's CAPTAIN VORPATRIL'S ALL...
# 188     Paolo Giordano's TASMANIA, to Judith Gurewich ...
# ...                                                   ...
# 325038  Lynn Reardon's BEYOND THE HOMESTRETCH: What I'...
# 325039  Lynn Reardon's BEYOND THE HOMESTRETCH: What I'...
# 325040  Bill Giovannetti's HOW TO KEEP YOUR INNER MESS...
# 325047  NYT bestselling author of Songs in Ordinary Ti...
# 325083  Sage Cohen's THE WRITING THE LIFE POETIC, an e...
#
#             Author_extracted        isbn13                author
# 9          jussi adler-olsen  9.781786e+12     Jussi Adler-Olsen  \
# 13         jussi adler-olsen  9.781786e+12     Jussi Adler-Olsen
# 60             leigh bardugo  9.781250e+12         Leigh Bardugo
# 181     lois mcmaster bujold  9.781618e+12  Lois McMaster Bujold
# 188           paolo giordano  9.788858e+12        Paolo Giordano
# ...                      ...           ...                   ...
# 325038          lynn reardon  9.781577e+12          Lynn Reardon
# 325039          lynn reardon  9.781577e+12          Lynn Reardon
# 325040      bill giovannetti  9.781854e+12      Bill Giovannetti
# 325047   mary mcgarry morris  9.780307e+12   Mary McGarry Morris
# 325083            sage cohen  9.781583e+12            Sage Cohen
#
#                                                     title datepublished
# 9                                      The Shadow Murders           NaT  \
# 13                                            Victim 2117    2020-03-05
# 60                                            Ninth House           NaT
# 181                          Captain Vorpatril's Alliance           NaT
# 188                                              Tasmania           NaT
# ...                                                   ...           ...
# 325038                             Beyond the Homestretch           NaN
# 325039                             Beyond the Homestretch           NaN
# 325040  How to Keep Your Inner Mess from Trashing Your...           NaN
# 325047                                    The Last Secret           NaN
# 325083                            Writing the Life Poetic           NaN
#
#                     author_l fuzz_ratio
# 9          jussi adler-olsen      100.0  \
# 13         jussi adler-olsen      100.0
# 60             leigh bardugo      100.0
# 181     lois mcmaster bujold      100.0
# 188           paolo giordano      100.0
# ...                      ...        ...
# 325038          lynn reardon      100.0
# 325039          lynn reardon      100.0
# 325040      bill giovannetti      100.0
# 325047   mary mcgarry morris      100.0
# 325083            sage cohen       92.0
#
#                                           title_extracted
# 9                                      THE SHADOW MURDERS
# 13                                                 VICTIM
# 60        NYT SIX OF CROWS CROOKED KINGDOM NINTH HOUSE UK
# 181                            CAPTAIN VORPATRIL ALLIANCE
# 188                                           TASMANIA NA
# ...                                                   ...
# 325038                             BEYOND THE HOMESTRETCH
# 325039                             BEYOND THE HOMESTRETCH
# 325040  HOW TO KEEP YOUR INNER MESS FROM TRASHING YOUR...
# 325047                             NYT THE LAST SECRET NA
# 325083                        THE WRITING THE LIFE POETIC
#
# [8157 rows x 24 columns]

# %%
test33['datepublished'] = pd.to_datetime(test33['datepublished']).dt.date
test33['Date'] = pd.to_datetime(test33['Date']).dt.date

test33['diff_days'] = test33.apply(lambda x : (x['datepublished'] - x['Date']).days,axis=1)
#test33[abs(diff.dt.days) <= pd.Timedelta(days=1460)]
# Out:
# <ipython-input-77-5548b6f2e827>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test33['datepublished'] = pd.to_datetime(test33['datepublished']).dt.date
# <ipython-input-77-5548b6f2e827>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test33['Date'] = pd.to_datetime(test33['Date']).dt.date
# <ipython-input-77-5548b6f2e827>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test33['diff_days'] = test33.apply(lambda x : (x['datepublished'] - x['Date']).days,axis=1)

# %%
x = test33
y = x.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

# %%
y[y['fuzz_ratio']>=95]
# Out:
#        advance_id       Rights Category           Genre        Date
# 81           1099            Children's   Graphic Novel  2023-02-18  \
# 156          2564  International rights      Children's  2023-01-16
# 294          4829          Audio rights            NONE  2022-11-09
# 400          6412  International rights         Fiction  2022-10-05
# 503          7892      Paperback rights            NONE  2022-08-22
# ...           ...                   ...             ...         ...
# 11140      164807           Film rights            NONE  2008-07-22
# 11195      165776  International rights         Fiction  2008-06-03
# 11290      167088  International rights     Non-fiction  2008-03-28
# 11300      167246               Fiction  General/ Other  2008-03-20
# 11353      167852  International rights         Fiction  2008-02-22
#
#            Author(s)                            Title
# 81     Gibson & Rori                WUTHERING HEIGHTS  \
# 156             NONE                 THE LION OF MARS
# 294    Carrie Aarons              WHEN STARS BURN OUT
# 400             NONE       THE SUMMER OF BROKEN RULES
# 503         TJ Klune        THE BONES BENEATH MY SKIN
# ...              ...                              ...
# 11140    Liza Palmer  CONVERSATIONS WITH THE FAT GIRL
# 11195           NONE                             NONE
# 11290           NONE                             NONE
# 11300   T. Greenwood                       TWO RIVERS
# 11353           NONE                             NONE
#
#                                               Publishers
# 81     ['Hannah Dussold', 'Andrews McMeel', 'Janna Mo...  \
# 156    ['Khai Minh', 'Clare Chi', 'The Grayhawk Agency']
# 294                ['Julie Constantine', 'Podium Audio']
# 400    ["Beatriz D'Oliveira", 'Rocco', 'Anna Luiza Ca...
# 503    ['Ali Fisher', 'Tor', 'Deidre Knight', 'The Kn...
# ...                                                  ...
# 11140           ['Christy Fletcher', 'Fletcher & Parry']
# 11195  ['Rizzoli', 'Maura Solinas', 'Piergiorgio Nico...
# 11290           ['New Star', 'Gray Tan', 'Jia-Xi Books']
# 11300  ['Peter Senftleben', 'Kensington', 'Henry Duno...
# 11353    ['Arcadia Culture', 'Gray Tan', 'Jia-Xi Books']
#
#       Big Publishing House Affilation   Advance Competition  ...
# 81                                NaN   24500.5         NaN  ...  \
# 156                               NaN   24500.5         NaN  ...
# 294                               NaN   24500.5         NaN  ...
# 400                               NaN   24500.5         YES  ...
# 503                               NaN  625000.0         NaN  ...
# ...                               ...       ...         ...  ...
# 11140                             NaN   74500.0         NaN  ...
# 11195                             NaN   24500.5         NaN  ...
# 11290                             NaN   24500.5         NaN  ...
# 11300                             NaN   24500.5         NaN  ...
# 11353                             NaN   24500.5         NaN  ...
#
#                                                      All  Author_extracted
# 81     Writer and artist team Gibson & Rori's WUTHERI...      emily bronte  \
# 156    Jennifer L. Holm's THE LION OF MARS, to Khai M...  jennifer l. holm
# 294    Carrie Aarons's WHEN STARS BURN OUT, to Julie ...     carrie aarons
# 400    K. L. Walther's THE SUMMER OF BROKEN RULES, to...     k. l. walther
# 503    NYT-bestselling and Lambda Literary Award-winn...          tj klune
# ...                                                  ...               ...
# 11140  Liza Palmer's CONVERSATIONS WITH THE FAT GIRL,...       liza palmer
# 11195  Italian rights to Jonathan Evison's ALL ABOUT ...   jonathan evison
# 11290  Simplified Chinese rights to investigative jou...    daniel estulin
# 11300  T. Greenwood's TWO RIVERS, about a good man wh...      t. greenwood
# 11353  Simplified Chinese rights to Dorothy Koomson's...   dorothy koomson
#
#              isbn13            author                                   title
# 81     9.781505e+12      Emily Bronte                       Wuthering Heights  \
# 156    9.780593e+12  Jennifer L. Holm                        The Lion of Mars
# 294    9.798712e+12     Carrie Aarons                     When Stars Burn Out
# 400    9.781728e+12     K. L. Walther              The Summer of Broken Rules
# 503    9.781732e+12          TJ Klune               The Bones Beneath My Skin
# ...             ...               ...                                     ...
# 11140  9.781539e+12       Liza Palmer         Conversations with the Fat Girl
# 11195  9.781594e+12   Jonathan Evison                          All About Lulu
# 11290  9.781634e+12    Daniel Estulin  The True Story of the Bilderberg Group
# 11300  9.781497e+12      T. Greenwood                              Two Rivers
# 11353  9.781472e+12   Dorothy Koomson                   My Best Friend's Girl
#
#       datepublished          author_l  fuzz_ratio
# 81       2020-12-04      emily bronte         100  \
# 156      2021-01-05  jennifer l. holm         100
# 294      2021-02-20     carrie aarons         100
# 400      2021-05-04     k. l. walther         100
# 503      2018-09-27          tj klune         100
# ...             ...               ...         ...
# 11140    2019-08-06       liza palmer         100
# 11195    2018-03-13   jonathan evison         100
# 11290    2018-04-05    daniel estulin          97
# 11300    2020-05-26      t. greenwood         100
# 11353    2020-03-17   dorothy koomson          95
#
#                                      title_extracted diff_days
# 81                                 WUTHERING HEIGHTS      -806
# 156                                 THE LION OF MARS      -741
# 294                              WHEN STARS BURN OUT      -627
# 400                       THE SUMMER OF BROKEN RULES      -519
# 503              NYT TJ THE BONES BENEATH MY SKIN NA     -1425
# ...                                              ...       ...
# 11140  CONVERSATIONS WITH THE FAT GIRL HBO ROME RWHS      4032
# 11195                                 ALL ABOUT LULU      3570
# 11290       THE TRUE STORY OF THE BILDERBERGER GROUP      3660
# 11300                                     TWO RIVERS      4450
# 11353                            MY BEST FRIEND GIRL      4407
#
# [757 rows x 25 columns]
