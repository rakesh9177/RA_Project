# %%
import os
import pandas as pd
import spacy
import re
from fuzzywuzzy import fuzz
# Load the English language model in spaCy
nlp = spacy.load('en_core_web_sm')

# %%
def get_advances_data():
    
    adv = pd.read_excel('author_advance_dataset.xlsx', index_col=0)
    adv = adv[~adv['Advance'].isna()]
    deals = {
    'NICE' : (1+49000)/2,
    'VERY NICE' : (50000 + 99000)/2,
    'GOOD' : (100000 + 250000)/2,
    'SIGNIFICANT' : (251000 + 499000)/2,
    'MAJOR' : (500000 + 750000)/2
    }
    adv['Advance'] = adv['Advance'].replace(deals)

    adv.reset_index(inplace=True)
    adv.rename(columns={'index': 'advance_id'}, inplace=True) 
    return adv

def get_printbook_title_data():
    
    book = pd.read_csv('books/booktitle_printbooks_new.csv')
    book = book[['author','title','isbn13', 'datepublished']]
    book['datepublished']  = pd.to_datetime(book['datepublished'], errors = 'coerce')
    #book.rename(columns={'datepublished' : 'datepublished_booktitle_data'})
    
    #Get only the first published date for a given isbn13
    book = book.sort_values('datepublished')
    book = book.groupby('isbn13').first().reset_index()
    
    return book

def get_Ebook_title_data():
    
    book = pd.read_csv('books/booktitle_ebook_new.csv')
    book = book[['author','title','isbn13', 'datepublished']]
    book['datepublished']  = pd.to_datetime(book['datepublished'], errors = 'coerce')
    #book.rename(columns={'datepublished' : 'datepublished_booktitle_data'})
    
    #Get only the first published date for a given isbn13
    book = book.sort_values('datepublished')
    book = book.groupby('isbn13').first().reset_index()
    
    return book

def extract_author_name_1(text):
    doc = nlp(text)
    for entity in doc.ents:
        if entity.label_ == 'PERSON' and ("'s" in entity.text or "'" in entity.text):
            return entity.text
    return None


def extract_author_name_2(text):
    doc = nlp(text)
    for entity in doc.ents:
        if entity.label_ == 'PERSON' :#and ("'s" in entity.text or "'" in entity.text):
            return entity.text
    return None

def author_extraction(adv):
    adv['Author_extracted'] = adv['All'].apply(lambda x: extract_author_name_1(x))
    adv.loc[(adv['Author_extracted'].isna()) & ((adv['Author(s)'] == 'NONE') | (adv['Author(s)'] == 'All')), 'Author_extracted'] = adv.loc[(adv['Author_extracted'].isna()) & ((adv['Author(s)'] == 'NONE') | (adv['Author(s)'] == 'All')), 'All'].apply(lambda x: extract_author_name_2(x))
    adv.loc[(adv['Author_extracted'].isna()) & (adv['Author(s)'] != 'NONE'), 'Author_extracted'] = adv.loc[(adv['Author_extracted'].isna()) & (adv['Author(s)'] != 'NONE'), 'Author(s)'] 
    adv['Author_extracted'] = adv['Author_extracted'].str.replace("'s", "")
    adv['Author_extracted'] = adv['Author_extracted'].str.replace("'", "")
    adv['Author_extracted'] = adv['Author_extracted'].str.lower()
    return adv


def levenshtein_ratio(s1, s2):
    return fuzz.token_sort_ratio(s1, s2)

def get_GAPI_books():
    d1 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv.csv')
    d1['Author'] = d1['Author'].astype(str)
    d2 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv_17440.csv')
    d2['Author'] = d2['Author'].astype(str)
    d3 = pd.read_csv('AuthorCrosswalkScraper/Unmatched_extraction_of_authors.csv')
    d3['Author'] = d3['Author'].astype(str)
    d4 = pd.read_csv('AuthorCrosswalkScraper/Google_Author_crosswalk_adv_x.csv')
    d4['Author'] = d4['Author'].astype(str)
    d = pd.concat([d1,d2],axis=0)
    d = pd.concat([d,d3], axis=0)
    d = pd.concat([d,d4], axis=0)
    d['Author'] = d['Author'].astype(str)
    d['Author'] = d['Author'].str.replace("[","")
    d['Author'] = d['Author'].str.replace("]","")
    d['Author'] = d['Author'].str.replace("'","")
    d['author_l'] = d['Author'].str.lower()
    d = d.drop(columns='Unnamed: 0')
    d.columns = ['author','title','datepublished','isbn13','author_l']
    
    return d

def merge_book_advances(book, adv):
    
    book_adv = pd.merge(book, adv, left_on='author_l', right_on='Author_extracted')
    book_adv['fuzz_ratio'] = book_adv.apply(lambda x : levenshtein_ratio(str(x['Title']).lower(), str(x['title']).lower()), axis=1)
    
    extract_all_caps = lambda text: ' '.join(re.findall(r'\b[A-Z]{2,}\b', text))
    book_adv['title_extracted'] = book_adv['All'].apply(extract_all_caps)
    
    book_adv = book_adv[~((book_adv['Title'] == 'NONE') & (book_adv['title_extracted']=="")) ]
    book_adv.loc[book_adv['Title'] == 'NONE', 'fuzz_ratio'] = book_adv.loc[book_adv['Title'] == 'NONE'].apply(lambda x : levenshtein_ratio(str(x['title_extracted']).lower(), str(x['title']).lower()), axis=1)
    
    book_adv['datepublished'] = book_adv['datepublished'].astype(str)
    book_adv['datepublished'] = pd.to_datetime(book_adv['datepublished'], errors='coerce')
    book_adv['datepublished'] = book_adv['datepublished'].apply(lambda x: x.date() if pd.notnull(x) and hasattr(x, 'date') else pd.NaT if pd.isnull(x) else pd.to_datetime(x[:10]).date() if len(x) == 10 else pd.to_datetime(x + '-12-31').date() if len(x) == 4 else pd.to_datetime(x + '-01').date() + pd.offsets.MonthEnd() if len(x) == 7 else x)
    '''
    book_adv_grouped = book_adv.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
    book_adv_grouped = book_adv_grouped.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
    '''
    book_adv_grouped = book_adv
    book_adv_grouped['datepublished'] = pd.to_datetime(book_adv_grouped['datepublished'])
    return book_adv_grouped

# %%
def any_merge(advance_data_this_row,sales_data):
    sales_advances = pd.DataFrame(columns=list(advance_data_this_row.columns)+ list(sales_data))
    isbn13_advance_data = advance_data_this_row['isbn13']
    
    for isbn in isbn13_advance_data:
        if isbn in df['isbn13']:
            sales_advances = pd.concat[[sales_advances, isbn13_advance_data[isbn13_advance_data['isbn13']==isbn]]]
    
    return sales_advances
    
    

def df_sales_merge():
    sales = pd.read_csv('sales/ebook_sales_aggregate.csv', index_col=0)
    sales = sales.groupby('isbn13',as_index=False).agg({'totalrevenue':'sum'}).reset_index()
    sale_title = pd.read_csv('AuthorCrosswalkScraper/All_isbn13_for_sales_by_Author_Agg.csv',index_col=0)
    sale_title = sale_title.rename(columns={
    'Author': 'author',
    'Title' : 'title',
    'PublishedDate': 'datepublished',
    'ISBN13' : 'isbn13'
    })
    sale_title['author'] = sale_title['author'].str.replace("'", "").str.replace("[", "").str.replace("]", "")
    sale_title = sale_title.drop_duplicates()
    #print(sales.columns, sale_title.columns)
    
    salesx = pd.merge(sale_title, sales, on='isbn13', how='outer')
    #salesx = salesx.drop(columns=['datepublished_x'])
    salesx = salesx.rename(columns={'datepublished_y' : 'datepublished',
                                   'title': 'sales_title',
                                   'author': 'sales_author'})
    mf = pd.merge(salesx, df , on = 'isbn13', how='outer')
    mf['sales_title'] = mf['sales_title'].fillna(mf['title'])
    mf['sales_author'] = mf['sales_author'].fillna(mf['author'])
    print(mf['advance_id'].value_counts())
    print(mf.columns)
    mf = mf.groupby(['sales_author','sales_title'], as_index=False).agg({'totalrevenue':'sum',
                                                                                  'Advance':'max'})
    mf = mf.loc[ (~mf['Advance'].isna()) & (mf['totalrevenue']>0)]
    return mf
    '''
    
    salesx = pd.merge(sale_title, salesx, on='author')
    salesx = salesx.drop_duplicates()
    salesx = salesx.drop(columns=['datepublished_x'])
    salesx = salesx.rename(columns={'datepublished_y' : 'datepublished'})
    #salex = pd.merge(salex)
    '''
    mf = pd.merge(salesx, df , left_on='isbn13', right_on = 'isbn13', how='outer')
    print(mf['advance_id'].value_counts())
    print(mf.columns)
    mf = mf.groupby(['sales_author','sales_title'], as_index=False).agg({'totalrevenue':'sum'})
    mf = mf.loc[mf['totalrevenue'] >0]
    
    #mf = pd.merge(mf, df, left_on=['sales_author','sales_title'], right_on=['author', 'title'])
    return mf
    
    #mf2 = pd.merge(salesx, df, left_on='isbn13_y', right_on='isbn13', how='right')
    
    #mf = pd.merge(salesx, df, left_on='isbn13_x', right_on='isbn13')
    #mf = pd.concat([mf1,mf2])
    
    mf = mf.drop(columns=['title','isbn13' ])
    mf = mf.drop_duplicates()
    #print(mf.shape, mf.columns)
    print(mf.columns, mf.head())
        
    kf = pd.merge(mf,sale_title, left_on=['author_x','title_x'], right_on=['author','title'], how='inner')
    print(kf.columns,kf.shape, kf.head())
    kf = kf.groupby(['author_x','title_x','datepublished_x'], as_index=False).agg({'totalrevenue':'sum'})
    #kf = kf.groupby('datepublished_x', as_index=False).agg({'totalrevenue':'sum'})
    
    '''
    salesx = pd.merge(sales, sale_title, on='isbn13')
    salesx = salesx.drop(columns=['datepublished_y'])
    salesx = salesx.rename(columns={'datepublished_x' : 'datepublished'})
    print(salesx.columns)
    
    salesxx = pd.merge( salesx,sale_title, on=['author','title'])
    salesxx = salesxx.drop(columns=['datepublished_y'])
    salesxx = salesxx.rename(columns={'datepublished_x' : 'datepublished'})
    print(salesxx.columns)
    
    mf1 = pd.merge(salesxx, df, left_on='isbn13_x', right_on='isbn13')
    mf2 = pd.merge(salesxx, df, left_on='isbn13_y', right_on='isbn13')
    mf = pd.concat([mf1,mf2])
    
    '''
    '''
    sales_x = pd.merge(df, sale_title, on=['isbn13'])
    #sales_x = pd.merge(sales_x, sale_title, on=['author','title'])
    #sales_x = sales_x.drop(columns=['datepublished_y','datepublished'])
    print(sales_x.columns, sales_x.shape)
    mm = pd.merge(sales_x, sale_title, left_on=['author_x','title_x'], right_on=['author','title'], how='inner')
    #mn = pd.merge(mm,sales, on='isbn13')
    mm =mm.drop(columns=['datepublished_y','datepublished'])
    print(mm.columns)
    m1 = pd.merge(mm, sales, left_on=['isbn13_x'] , right_on=['isbn13'] , how='inner')
    m2 = pd.merge(mm, sales, left_on=['isbn13_y'] , right_on=['isbn13'] , how='inner')
    mn = pd.concat([m1,m2])
    mn = mn.drop_duplicates()
    #mm = pd.merge(sales_x, df, on= ['author','title'])
    '''
    return salesx
    
def df_sales_merge_time_series():
    i=0
    sale_title = pd.read_csv('AuthorCrosswalkScraper/All_isbn13_for_sales_by_Author_Agg.csv',index_col=0)
    sale_title = sale_title.rename(columns={
    'Author': 'author',
    'Title' : 'title',
    'PublishedDate': 'datepublished',
    'ISBN13' : 'isbn13'
    })
    sale_title['author'] = sale_title['author'].str.replace("'", "").str.replace("[", "").str.replace("]", "")
    sale_title = sale_title.drop_duplicates()
    for file in os.listdir('sales/printbook/'):
        sales = pd.read_csv(f'sales/printbook/{file}')
        sales = sales.groupby('isbn13',as_index=False).agg({'totalrevenue':'sum'}).reset_index()
        
        
        salesx = pd.merge(sale_title, sales, on='isbn13', how='outer')
        #salesx = salesx.drop(columns=['datepublished_x'])
        salesx = salesx.rename(columns={'datepublished_y' : 'datepublished',
                                       'title': 'sales_title',
                                       'author': 'sales_author'})
        mf = pd.merge(salesx, df , left_on='isbn13', right_on = 'isbn13', how='outer')
        #print(mf['advance_id'].value_counts())
        #print(mf.columns)
        mf = mf.groupby(['sales_author','sales_title','isbn13'], as_index=False).agg({'totalrevenue':'sum'})
        mf = mf.loc[mf['totalrevenue'] >0]
        mf['sales_month_year'] = file[-12:-6]
        mf['sales_month_year'] = pd.to_datetime(mf['sales_month_year'], format='%Y%m')
        if i==0:
            xf = mf
            i+=1
            continue
        xf = pd.concat([xf, mf])
        print(f"{file} - processed")
    #mf = pd.merge(mf, df, left_on=['sales_author','sales_title'], right_on=['author', 'title'])
    return xf

# %%
df_sales_merge()
# Out:
# advance_id
# 160215.0    1
# 128031.0    1
# 136221.0    1
# 129130.0    1
# 160789.0    1
#            ..
# 155392.0    1
# 153317.0    1
# 154164.0    1
# 167932.0    1
# 7031.0      1
# Name: count, Length: 15799, dtype: int64
# Index(['sales_title', 'sales_author', 'datepublished_x', 'isbn13', 'index',
#        'totalrevenue', 'author', 'title', 'datepublished_y', 'author_l',
#        'advance_id', 'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title',
#        'Publishers', 'Big Publishing House Affilation', 'Advance',
#        'Competition', 'Awards', 'Bestseller', 'Self Publishing', 'Debut',
#        'Series', 'All', 'Author_extracted', 'fuzz_ratio', 'title_extracted'],
#       dtype='object')
#                 sales_author                               sales_title
# 4198            Aaron Blabey                              Pig the Star  \
# 4265     Aaron Bobrow-Strain      The Death and Life of Aida Hernandez
# 4439             Abbi Glines                            After the Game
# 4580           Abbie Greaves                      The Silent Treatment
# 4737        Abigail Hing Wen                          Loveboat, Taipei
# ...                      ...                                       ...
# 358415            Wu Ming-Yi                        The Stolen Bicycle
# 358755      Yanis Varoufakis  Talking to My Daughter About the Economy
# 359135             Yigal Zur                       Death in Shangri-La
# 359145  Yiota Giannakopoulou                     The Gift of the Greek
# 359541      Yotam Ottolenghi                         Ottolenghi Simple
#
#         totalrevenue   Advance
# 4198        122877.0   74500.0
# 4265        724289.0  175000.0
# 4439      16239291.0  625000.0
# 4580         27638.0  375000.0
# 4737        409731.0  625000.0
# ...              ...       ...
# 358415      392968.0   24500.5
# 358755     2979612.0  175000.0
# 359135       59233.0   24500.5
# 359145      409913.0   24500.5
# 359541     8146563.0   24500.5
#
# [534 rows x 4 columns]

# %%
#step 1
d = get_GAPI_books()
#step 2
adv = get_advances_data()
adv = author_extraction(adv)

# %%
#step 3
merg = merge_book_advances(d, adv)
#step 4
f = merg[merg['fuzz_ratio']>=95]
f = f.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
f = f.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
print("step 4",f.shape, f['advance_id'].unique().shape, f['isbn13'].unique().shape, f['author_l'].unique().shape)

merg = merg[(~merg['isbn13'].isin(f['isbn13'])) & (~merg['advance_id'].isin(f['advance_id']))]
#step 5
filtered_merg = merg[((merg['datepublished'] - merg['Date']).dt.days <=1460) & ((merg['datepublished'] - merg['Date']).dt.days >=90) & (merg['fuzz_ratio']>=80)]
filtered_merg = filtered_merg.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
filtered_merg = filtered_merg.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
print("step 5",filtered_merg.shape, filtered_merg['advance_id'].unique().shape, filtered_merg['isbn13'].unique().shape, filtered_merg['author_l'].unique().shape)

merg = merg[(~merg['isbn13'].isin(filtered_merg['isbn13'])) & (~merg['advance_id'].isin(filtered_merg['advance_id']))]
#step 6
df = pd.concat([f,filtered_merg], axis=0)
print("step 6 = step 4 + step 5",df.shape, df['advance_id'].unique().shape, df['isbn13'].unique().shape, df['author_l'].unique().shape)
#df = df.drop_duplicates()
#df = df.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
#df = df.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])

#step 7
rem = merg[(~merg['isbn13'].isin(df['isbn13'])) & (~merg['advance_id'].isin(df['advance_id']))]
rem = merg[((merg['datepublished'] - merg['Date']).dt.days <=1460) & ((merg['datepublished'] - merg['Date']).dt.days >=90)]
rem = rem.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
rem = rem.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
print("step 7", rem.shape, rem['advance_id'].unique().shape, rem['isbn13'].unique().shape, rem['author_l'].unique().shape)
df = pd.concat([df,rem], axis=0)
print("final merge",df.shape, df['advance_id'].unique().shape, df['isbn13'].unique().shape, df['author_l'].unique().shape)
#df = df.drop_duplicates()
#df = df.groupby('advance_id', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
#df = df.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['fuzz_ratio'].idxmax()])
#print(df.shape, df['advance_id'].unique().shape, df['isbn13'].unique().shape, df['author_l'].unique().shape)
# Out:
# step 4 (8217, 24) (8217,) (8217,) (7213,)
# step 5 (675, 24) (675,) (675,) (650,)
# step 6 = step 4 + step 5 (8892, 24) (8892,) (8892,) (7576,)
# step 7 (6907, 24) (6907,) (6907,) (5557,)
# final merge (15799, 24) (15799,) (15799,) (11810,)

# %%
adv
# Out:
#        advance_id       Rights Category                             Genre
# 0               2  International rights                        UK Fiction  \
# 1               4  International rights                           Fiction
# 2               7               Fiction                            Horror
# 3              13            Children's              Picture Book Fiction
# 4              22            Children's                     Graphic Novel
# ...           ...                   ...                               ...
# 34292      168767           Non-fiction                           History
# 34293      168773            Children's               Young Adult Fiction
# 34294      168780           Non-fiction  Advice/ Relationships/ Self-Help
# 34295      168797           Non-fiction                            How-To
# 34296      168799           Non-fiction                            Memoir
#
#             Date                              Author(s)
# 0     2023-03-15                Kynpham Sing Nongkynrih  \
# 1     2023-03-15                                   NONE
# 2     2023-03-15                         Chance Forshee
# 3     2023-03-15        ['Debra Buschman', 'Tom Uleau']
# 4     2023-03-14                              Junepurrr
# ...          ...                                    ...
# 34292 2008-01-07                            Stefan Aust
# 34293 2008-01-07                    David Macinnis Gill
# 34294 2008-01-06                                   NONE
# 34295 2008-01-04        ['Linda Meyers', 'John Meyers']
# 34296 2008-01-04  ["Chris O'Dell", 'Katherine Ketcham']
#
#                              Title
# 0                   FUNERAL NIGHTS  \
# 1               THE SHADOW MURDERS
# 2      A TERRIFYING TOME OF TERROR
# 3          THE KNIGHT & HIS TRUSTY
# 4                          SUBZERO
# ...                            ...
# 34292               BAADER-MEINHOF
# 34293               SOUL ENCHILADA
# 34294                         NONE
# 34295               TOSSED & FOUND
# 34296              LADY IN WAITING
#
#                                               Publishers
# 0      ['Stefan Tobler', 'And Other Stories', 'Tara T...  \
# 1      ['Fantasy Foundation', 'Ann Huang', 'The Grayh...
# 2         ['Jennifer Barnes', 'Raw Dog Screaming Press']
# 3                 ['Michele McAvoy', 'The Little Press']
# 4      ['Desiree Rodriguez', 'Oni Press', 'Britt Sies...
# ...                                                  ...
# 34292          ['Cybele Tom', 'Oxford University Press']
# 34293  ['Virginia Duncan', "Harper Children's", 'Rose...
# 34294                                               NONE
# 34295  ['Dervla Kelly', 'Stewart, Tabori & Chang', 'S...
# 34296  ['Trish Todd', 'Touchstone Fireside', 'Linda L...
#
#       Big Publishing House Affilation   Advance Competition Awards Bestseller
# 0                                 NaN   24500.5         NaN    NaN        NaN  \
# 1                                 NaN   24500.5         NaN    NaN        NaN
# 2                                 NaN   24500.5         NaN    NaN        NaN
# 3                                 NaN   24500.5         NaN    NaN        NaN
# 4                                 NaN   74500.0         NaN    NaN        NaN
# ...                               ...       ...         ...    ...        ...
# 34292                             NaN   24500.5         NaN    NaN        NaN
# 34293                          Harper  175000.0         YES    NaN        NaN
# 34294                             NaN  175000.0         YES    NaN        NaN
# 34295                             NaN   24500.5         NaN    NaN        NaN
# 34296                             NaN  375000.0         YES    NaN        NaN
#
#       Self Publishing Debut Series
# 0                 NaN   NaN    NaN  \
# 1                 NaN   NaN    NaN
# 2                 NaN   NaN    NaN
# 3                 NaN   NaN    NaN
# 4                 NaN   NaN    NaN
# ...               ...   ...    ...
# 34292             NaN   NaN    NaN
# 34293             NaN   NaN    NaN
# 34294             NaN   NaN    NaN
# 34295             NaN   NaN    NaN
# 34296             NaN   NaN    NaN
#
#                                                      All
# 0      Indian writer Kynpham Sing Nongkynrih's FUNERA...  \
# 1      Jussi Adler-Olsen's THE SHADOW MURDERS, to Fan...
# 2      The Curator of Horror, a bookseller, and host ...
# 3      SCBWI Wisconsin Regional Advisor Debra Buschma...
# 4      Creator of the webcomic series of the same nam...
# ...                                                  ...
# 34292  Der Spiegel's Editor-in-Chief Stefan Aust's BA...
# 34293  David Macinnis Gill's SOUL ENCHILADA, in which...
# 34294  Peg Streep's MEAN MOTHERS, exploring the psych...
# 34295  Interior designers Linda Meyers and John Meyer...
# 34296  Tour manager, friend, lover, and confidante to...
#
#                   Author_extracted
# 0          kynpham sing nongkynrih
# 1                jussi adler-olsen
# 2                   chance forshee
# 3      [debra buschman, tom uleau]
# 4                        junepurrr
# ...                            ...
# 34292                  der spiegel
# 34293          david macinnis gill
# 34294                   peg streep
# 34295                  john meyers
# 34296                  chris odell
#
# [34297 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['author', 'title', 'datepublished', 'isbn13', 'author_l', 'advance_id',
#        'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All',
#        'Author_extracted', 'fuzz_ratio', 'title_extracted'],
#       dtype='object')

# %%
df.to_csv('data_before_sales_merge.csv')

# %%
sales = pd.read_csv('sales/ebook_sales_aggregate.csv', index_col=0)

# %%
sale_title = pd.read_csv('AuthorCrosswalkScraper/All_isbn13_for_sales_by_Author_Agg.csv',index_col=0)

# %%
sale_title = sale_title.rename(columns={
    'Author': 'author',
    'Title' : 'title',
    'PublishedDate': 'datepublished',
    'ISBN13' : 'isbn13'
})

# %%
sale_title['author'] = sale_title['author'].str.replace("'", "").str.replace("[", "").str.replace("]", "")

# %%
kx = pd.merge(sales, sale_title, on='isbn13')

# %%
kx.columns
# Out:
# Index(['isbn13', 'datepublished_x', 'totalrevenue', 'totalunits', 'price',
#        'title', 'author', 'datepublished_y'],
#       dtype='object')

# %%
kx = pd.merge(kx, sale_title, on=['author', 'title'])

# %%
kx['isbn13_y'].unique().shape
# Out:
# (14439,)

# %%
kx = kx.rename(columns={'datepublished':'datepublished_z'})

# %%
shpa = pd.merge(kx, df, left_on='isbn13_y' , right_on='isbn13')

# %%
shpa
# Out:
#          isbn13_x datepublished_x  totalrevenue  totalunits        price
# 0    9.780062e+12      2015-03-03          7182          18   403.333333  \
# 1    9.780062e+12      2017-12-05      12716194       12413  1224.837576
# 2    9.780062e+12      2018-05-01       4586380        4281  1068.603214
# 3    9.780062e+12      2018-06-03             0           0  1099.000000
# 4    9.780062e+12      2023-11-06             0           0   853.000000
# ..            ...             ...           ...         ...          ...
# 414  9.781985e+12      2020-07-07         69537          81   889.858586
# 415  9.781985e+12      2019-05-21       1063507         855  1244.488599
# 416  9.781985e+12      2019-12-31        998451         833  1213.104895
# 417  9.782214e+12      2018-09-26         35063          20  1880.473684
# 418  9.783641e+12      2018-03-05        539788         381  1425.031830
#
#                    title_x      author_x datepublished_y datepublished_z
# 0           The Memory Key     Liana Liu            2015            2015  \
# 1             The Saboteur      Paul Kix            2017            2017
# 2             Not That Bad    Roxane Gay            2018            2018
# 3             Not That Bad    Roxane Gay            2018            2018
# 4             Not That Bad    Roxane Gay            2018            2018
# ..                     ...           ...             ...             ...
# 414             Kill Orbit     Joel Dane            2020            2020
# 415           Star-Crossed  Minnie Darke            2019            2019
# 416   A Woman Makes a Plan     Maye Musk            2019            2019
# 417  Un gentleman à Moscou   Amor Towles            2018            2018
# 418  Der Ernährungskompass      Bas Kast            2018            2018
#
#           isbn13_y  ... Competition Awards Bestseller  Self Publishing Debut
# 0    9780062306661  ...         YES    NaN        NaN              NaN   YES  \
# 1    9780062322548  ...         NaN    NaN        NaN              NaN   NaN
# 2    9780062413505  ...         NaN    NaN        NaN              NaN   NaN
# 3    9780062413505  ...         NaN    NaN        NaN              NaN   NaN
# 4    9780062413505  ...         NaN    NaN        NaN              NaN   NaN
# ..             ...  ...         ...    ...        ...              ...   ...
# 414  9781984802576  ...         YES    NaN        NaN              NaN   NaN
# 415  9781984822840  ...         YES    YES        NaN              NaN   NaN
# 416  9781984878519  ...         YES    NaN        NaN              NaN   NaN
# 417  9782213704296  ...         NaN    NaN        NaN              NaN   NaN
# 418  9783641201074  ...         YES    NaN        NaN              NaN   NaN
#
#      Series                                                All
# 0       NaN  University of Minnesota MFA graduate Liana Liu...  \
# 1       NaN  Journalist Paul Kix's THE NOBLE ASSASSIN, the ...
# 2       NaN  Roxane Gay's NOT THAT BAD, to Folio (China), i...
# 3       NaN  Roxane Gay's NOT THAT BAD, to Folio (China), i...
# 4       NaN  Roxane Gay's NOT THAT BAD, to Folio (China), i...
# ..      ...                                                ...
# 414     NaN  Joel Dane's CRY PILOT, BURN CYCLE, and KILL OR...
# 415     NaN  Minnie Darke's STAR-CROSSED, pitch as in the v...
# 416     NaN  Maye Musk's A WOMAN MAKES A PLAN, to Stefan Ma...
# 417     NaN  Rules of Civility author Amor Towles next two ...
# 418     NaN  Bas Kast's DER ERNAHRUNGSKOMPASS, to Business ...
#
#     Author_extracted fuzz_ratio                           title_extracted
# 0          liana liu        100                     MFA THE MEMORY KEY NA
# 1           paul kix         53                        THE NOBLE ASSASSIN
# 2         roxane gay        100                              NOT THAT BAD
# 3         roxane gay        100                              NOT THAT BAD
# 4         roxane gay        100                              NOT THAT BAD
# ..               ...        ...                                       ...
# 414        joel dane         49        CRY PILOT BURN CYCLE KILL ORBIT SF
# 415     minnie darke        100  STAR CROSSED THE ROSIE PROJECT NA UK IPG
# 416        maye musk        100                          WOMAN MAKES PLAN
# 417      amor towles         33                                     NA UK
# 418         bas kast         98                     DER ERNAHRUNGSKOMPASS
#
# [419 rows x 34 columns]

# %%
shpa.shape
# Out:
# (419, 34)

# %%
shpa2 = pd.merge(shpa, sale_title, on='isbn13')

# %%
shpa2
# Out:
#            isbn13 datepublished_x  totalrevenue  totalunits        price
# 0    9.780062e+12      2015-03-03          7182          18   403.333333  \
# 1    9.780062e+12      2017-12-05      12716194       12413  1224.837576
# 2    9.780062e+12      2018-05-01       4586380        4281  1068.603214
# 3    9.780062e+12      2018-06-03             0           0  1099.000000
# 4    9.780062e+12      2023-11-06             0           0   853.000000
# ..            ...             ...           ...         ...          ...
# 274  9.781985e+12      2020-07-07         69537          81   889.858586
# 275  9.781985e+12      2019-05-21       1063507         855  1244.488599
# 276  9.781985e+12      2019-12-31        998451         833  1213.104895
# 277  9.782214e+12      2018-09-26         35063          20  1880.473684
# 278  9.783641e+12      2018-03-05        539788         381  1425.031830
#
#          author_x                title_x datepublished_y      author_l
# 0       Liana Liu         The Memory Key      2015-01-01     liana liu  \
# 1        Paul Kix           The Saboteur      2017-01-01      paul kix
# 2      Roxane Gay           Not That Bad      2018-01-01    roxane gay
# 3      Roxane Gay           Not That Bad      2018-01-01    roxane gay
# 4      Roxane Gay           Not That Bad      2018-01-01    roxane gay
# ..            ...                    ...             ...           ...
# 274     Joel Dane             Kill Orbit      2020-01-01     joel dane
# 275  Minnie Darke           Star-Crossed      2019-01-01  minnie darke
# 276     Maye Musk   A Woman Makes a Plan      2019-01-01     maye musk
# 277   Amor Towles  Un gentleman à Moscou      2018-01-01   amor towles
# 278      Bas Kast  Der Ernährungskompass      2018-01-01      bas kast
#
#      advance_id  ... Self Publishing Debut Series
# 0        124290  ...             NaN   YES    NaN  \
# 1        120953  ...             NaN   NaN    NaN
# 2         39661  ...             NaN   NaN    NaN
# 3         39661  ...             NaN   NaN    NaN
# 4         39661  ...             NaN   NaN    NaN
# ..          ...  ...             ...   ...    ...
# 274       65841  ...             NaN   NaN    NaN
# 275       66743  ...             NaN   NaN    NaN
# 276       46356  ...             NaN   NaN    NaN
# 277       90863  ...             NaN   NaN    NaN
# 278       61933  ...             NaN   NaN    NaN
#
#                                                    All Author_extracted
# 0    University of Minnesota MFA graduate Liana Liu...        liana liu  \
# 1    Journalist Paul Kix's THE NOBLE ASSASSIN, the ...         paul kix
# 2    Roxane Gay's NOT THAT BAD, to Folio (China), i...       roxane gay
# 3    Roxane Gay's NOT THAT BAD, to Folio (China), i...       roxane gay
# 4    Roxane Gay's NOT THAT BAD, to Folio (China), i...       roxane gay
# ..                                                 ...              ...
# 274  Joel Dane's CRY PILOT, BURN CYCLE, and KILL OR...        joel dane
# 275  Minnie Darke's STAR-CROSSED, pitch as in the v...     minnie darke
# 276  Maye Musk's A WOMAN MAKES A PLAN, to Stefan Ma...        maye musk
# 277  Rules of Civility author Amor Towles next two ...      amor towles
# 278  Bas Kast's DER ERNAHRUNGSKOMPASS, to Business ...         bas kast
#
#     fuzz_ratio                           title_extracted
# 0          100                     MFA THE MEMORY KEY NA  \
# 1           53                        THE NOBLE ASSASSIN
# 2          100                              NOT THAT BAD
# 3          100                              NOT THAT BAD
# 4          100                              NOT THAT BAD
# ..         ...                                       ...
# 274         49        CRY PILOT BURN CYCLE KILL ORBIT SF
# 275        100  STAR CROSSED THE ROSIE PROJECT NA UK IPG
# 276        100                          WOMAN MAKES PLAN
# 277         33                                     NA UK
# 278         98                     DER ERNAHRUNGSKOMPASS
#
#                    title_y      author_y datepublished
# 0           The Memory Key     Liana Liu          2015
# 1             The Saboteur      Paul Kix          2017
# 2             Not That Bad    Roxane Gay          2018
# 3             Not That Bad    Roxane Gay          2018
# 4             Not That Bad    Roxane Gay          2018
# ..                     ...           ...           ...
# 274             Kill Orbit     Joel Dane          2020
# 275           Star-Crossed  Minnie Darke          2019
# 276   A Woman Makes a Plan     Maye Musk          2019
# 277  Un gentleman à Moscou   Amor Towles          2018
# 278  Der Ernährungskompass      Bas Kast          2018
#
# [279 rows x 31 columns]

# %%
shpa['isbn13'].unique().shape
# Out:
# (508,)

# %%
shpa['author'] = shpa['author'].str.replace("'", "").str.replace("[", "").str.replace("]", "")

# %%
ISBN13_j = pd.merge(df, sale_title, on='isbn13')

# %%
ISBN13_j.columns
# Out:
# Index(['author_x', 'title_x', 'datepublished_x', 'isbn13', 'author_l',
#        'advance_id', 'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title',
#        'Publishers', 'Big Publishing House Affilation', 'Advance',
#        'Competition', 'Awards', 'Bestseller', 'Self Publishing', 'Debut',
#        'Series', 'All', 'Author_extracted', 'fuzz_ratio', 'title_extracted',
#        'title_y', 'author_y', 'datepublished_y'],
#       dtype='object')

# %%
pd.merge(df, sale_title, on=['author','title'])
# Out:
#                     author                      title datepublished_x
# 0           Madeleine Roux                     Asylum      2013-01-01  \
# 1             Jeff Jackson               Mira Corpora      2014-01-01
# 2             Kendall Ryan              Resisting Her      2015-01-01
# 3              Dianne Lake       Member of the Family      2018-01-01
# 4           Nnedi Okorafor            Who Fears Death      2018-01-01
# ...                    ...                        ...             ...
# 3329        J.R. Johansson         Condenado a muerte      2015-01-01
# 3330      Patrick Rothfuss       A Música do Silêncio      2015-01-01
# 3331        Hailey Edwards               Gray Tidings      2022-01-01
# 3332       Alexandre Dumas  The Black Tulip Annotated      2021-01-01
# 3333  Christopher Ruocchio           The Lesser Devil      2020-01-01
#
#            isbn13_x              author_l  advance_id       Rights Category
# 0     9780007538256        madeleine roux      134628            Children's  \
# 1     9780007586370          jeff jackson      126531               Fiction
# 2     9780008134051          kendall ryan      125056               Fiction
# 3     9780008274764           dianne lake       81901           Non-fiction
# 4     9780008288747        nnedi okorafor      161284               Fiction
# ...             ...                   ...         ...                   ...
# 3329  9789877474404        j.r. johansson      124480            Children's
# 3330  9789892330723      patrick rothfuss      130549               Fiction
# 3331  9798360451945        hailey edwards       59350  International rights
# 3332  9798591189884       alexandre dumas       43532               Fiction
# 3333  9798617354135  christopher ruocchio       93513               Fiction
#
#                     Genre       Date
# 0     Young Adult Fiction 2012-03-08  \
# 1                   Debut 2013-01-10
# 2                 Romance 2013-03-02
# 3                  Memoir 2017-01-12
# 4         Sci-Fi/ Fantasy 2009-01-28
# ...                   ...        ...
# 3329  Young Adult Fiction 2013-03-20
# 3330      Sci-Fi/ Fantasy 2012-08-08
# 3331              Fiction 2018-10-17
# 3332       General/ Other 2020-01-28
# 3333      Sci-Fi/ Fantasy 2016-02-03
#
#                                       Author(s)  ... Bestseller
# 0                                Madeleine Roux  ...        NaN  \
# 1                                  Jeff Jackson  ...        NaN
# 2                                  Kendall Ryan  ...        YES
# 3                                   Dianne Lake  ...        NaN
# 4                                Nnedi Okorafor  ...        NaN
# ...                                         ...  ...        ...
# 3329                             J.R. Johansson  ...        NaN
# 3330                           Patrick Rothfuss  ...        YES
# 3331                                       NONE  ...        NaN
# 3332  ['Lawrence Ellsworth', 'Alexandre Dumas']  ...        NaN
# 3333                       Christopher Ruocchio  ...        NaN
#
#      Self Publishing Debut  Series
# 0                NaN   NaN     NaN  \
# 1                NaN   NaN     NaN
# 2                NaN   NaN     NaN
# 3                NaN   NaN     NaN
# 4                NaN   NaN     NaN
# ...              ...   ...     ...
# 3329             NaN   NaN     NaN
# 3330             NaN   NaN     NaN
# 3331             NaN   NaN     NaN
# 3332             NaN   NaN     NaN
# 3333             NaN   NaN     NaN
#
#                                                     All      Author_extracted
# 0     SADIE WALKER IS STRANDED author Madeleine Roux...        madeleine roux  \
# 1     Jeff Jackson's MIRA CORPORA, the story of an 1...          jeff jackson
# 2     NYT bestselling author Kendall Ryan's RESISTIN...          kendall ryan
# 3     Dianne Lake's MEMBER OF THE FAMILY: My Story o...           dianne lake
# 4     Nnedi Okorafor's WHO FEARS DEATH?, Nigerian-Am...        nnedi okorafor
# ...                                                 ...                   ...
# 3329  INSOMNIA author J.R. Johansson's untitled new ...        j.r. johansson
# 3330  New York Times bestselling author of The Name ...      patrick rothfuss
# 3331  Hailey Edwards's BAYOU BORN and BONE DRIVEN, t...        hailey edwards
# 3332  Translator of THE THREE MUSKETEERS, TWENTY YEA...       alexandre dumas
# 3333  Christopher Ruocchio's THE MURDERED SUM, Book ...  christopher ruocchio
#
#      fuzz_ratio                                    title_extracted
# 0           100                    SADIE WALKER IS STRANDED ASYLUM  \
# 1           100                                    MIRA CORPORA NA
# 2           100                           NYT RESISTING HER FBI NA
# 3           100                               MEMBER OF THE FAMILY
# 4           100                             WHO FEARS DEATH DAW NA
# ...         ...                                                ...
# 3329         23                                           INSOMNIA
# 3330         19                                                DAW
# 3331         35                             BAYOU BORN BONE DRIVEN
# 3332         28  THE THREE MUSKETEERS TWENTY YEARS AFTER THE RE...
# 3333         50                         THE MURDERED SUM DAW NA UK
#
#      datepublished_y       isbn13_y
# 0               2013  9780007538256
# 1               2014  9780007586370
# 2               2015  9780008134051
# 3               2018  9780008274764
# 4               2020  9780756417109
# ...              ...            ...
# 3329            2015  9789877474404
# 3330            2015  9789892330723
# 3331            2022  9798360451945
# 3332            2021  9798591189884
# 3333            2020  9798617354135
#
# [3334 rows x 26 columns]

# %%
fm = pd.merge(shpa, df, left_on='author', right_on = 'author')
fm['datepublished_y'] = pd.to_datetime(fm['datepublished_y'])

# %%
fm['fuzz_ratio_1'] = fm.apply(lambda x : levenshtein_ratio(str(x['title_x']).lower(), str(x['title_y']).lower()), axis=1)

# %%
fm[fm['fuzz_ratio_1'] >= 70]
# Out:
#                         author             title_x datepublished_x
# 24                    Paul Kix        The Saboteur      2017-12-05  \
# 49          Erin Entrada Kelly        You Go First      2018-04-10
# 104          Heather Kaczynski  Dare Mighty Things      2017-10-10
# 106               Angie Thomas      On the Come Up      2019-02-05
# 113                 Alisha Rai     The Right Swipe      2019-08-06
# ...                        ...                 ...             ...
# 1578              Ernest Cline    Ready player one      2018-03-15
# 1608  Rachel DeLoache Williams      My friend Anna      2019-08-19
# 1664           Richard Wiseman         59 segundos      2015-03-26
# 1667           Richard Wiseman         59 segundos      2015-03-26
# 1745            Garrard Conley          Boy erased      2019-01-04
#
#            isbn13_x datepublished_y  totalrevenue  totalunits        price
# 24    9780062322548      2017-12-05      12716194       12413  1224.837576  \
# 49    9780062414205      2018-04-10       1349539        2018   734.842105
# 104   9780062479891      2017-10-10        366170        1069   831.631373
# 106   9780062498571      2019-02-05       9162855        8584  1134.668387
# 113   9780062877864      2019-07-02        277994         278   997.362573
# ...             ...             ...           ...         ...          ...
# 1578  9782749935881      2018-03-15         88736          64  1425.960784
# 1608  9783641258191      2019-08-19         90683          86   970.983516
# 1664  9788490068519      2015-03-16         43883          52   874.266667
# 1667  9788490068519      2018-08-28         11687          13   910.766667
# 1745  9788551004128      2019-01-04          2418           3   761.314961
#
#                  title_y datepublished  ...  Awards Bestseller
# 24          The Saboteur    2017-01-01  ...     NaN        NaN  \
# 49          You Go First    2018-01-01  ...     NaN        NaN
# 104   Dare Mighty Things    2017-01-01  ...     NaN        NaN
# 106       On the Come Up           NaT  ...     NaN        NaN
# 113      The Right Swipe    2019-01-01  ...     NaN        NaN
# ...                  ...           ...  ...     ...        ...
# 1578          Player one    2018-01-01  ...     NaN        NaN
# 1608      My Friend Anna    2019-01-01  ...     NaN        NaN
# 1664          59 Seconds    2010-01-01  ...     NaN        NaN
# 1667          59 Seconds    2010-01-01  ...     NaN        NaN
# 1745          Boy Erased           NaT  ...     NaN        NaN
#
#       Self Publishing Debut Series
# 24                NaN   NaN    NaN  \
# 49                NaN   NaN    NaN
# 104               NaN   YES    NaN
# 106               NaN   NaN    NaN
# 113               NaN   NaN    NaN
# ...               ...   ...    ...
# 1578              NaN   NaN    NaN
# 1608              NaN   NaN    NaN
# 1664              NaN   NaN    NaN
# 1667              NaN   NaN    NaN
# 1745              NaN   NaN    NaN
#
#                                                     All
# 24    Journalist Paul Kix's THE NOBLE ASSASSIN, the ...  \
# 49    Author of the forthcoming BLACKBIRD FLY, Erin ...
# 104   Debut author Heather Kaczynski's new duology, ...
# 106   Angie Thomas's ON THE COME UP, to Moon (Nether...
# 113   Alisha Rai's A PERFECT MATCH, in which two riv...
# ...                                                 ...
# 1578  Author of Ready Player One and Armada Ernest C...
# 1608  Rachel DeLoache Williams's MY FRIEND ANNA, to ...
# 1664  Media psychologist Richard Wiseman's SIXTY SEC...
# 1667  Media psychologist Richard Wiseman's SIXTY SEC...
# 1745  Garrard Conley's BOY ERASED, to ClassAct (Thai...
#
#               Author_extracted fuzz_ratio
# 24                    paul kix         53  \
# 49          erin entrada kelly         41
# 104          heather kaczynski        100
# 106               angie thomas        100
# 113                 alisha rai         33
# ...                        ...        ...
# 1578              ernest cline         33
# 1608  rachel deloache williams        100
# 1664           richard wiseman         61
# 1667           richard wiseman         61
# 1745            garrard conley        100
#
#                                 title_extracted fuzz_ratio_1
# 24                           THE NOBLE ASSASSIN          100
# 49    BLACKBIRD FLY ALMOST VIRGIL YOU WERE HERE          100
# 104                    DARE MIGHTY THINGS NA UK          100
# 106                              ON THE COME UP          100
# 113                               PERFECT MATCH          100
# ...                                         ...          ...
# 1578                                         NA           77
# 1608                             MY FRIEND ANNA          100
# 1664                              SIXTY SECONDS           76
# 1667                              SIXTY SECONDS           76
# 1745                                 BOY ERASED          100
#
# [147 rows x 32 columns]

# %%
fm.columns
fm.shape
# Out:
# (1521, 28)

# %%
fm = fm[~fm['datepublished_y'].isna()]

# %%
fm.shape
# Out:
# (1449, 28)

# %%
fm
# Out:
#             isbn13 datepublished_x  totalrevenue  totalunits        price
# 0     9.780008e+12      2019-12-26          1480           1  1480.000000  \
# 1     9.780008e+12      2020-01-01             0           0  1473.000000
# 2     9.780008e+12      2020-03-05         25201          20  1309.250000
# 3     9.780008e+12      2021-04-06          1899           1  1680.235294
# 4     9.780062e+12      2017-10-03       1252305        1127  1048.526147
# ...            ...             ...           ...         ...          ...
# 1516  9.781989e+12      2020-01-07         90107         101   874.060606
# 1517  9.782214e+12      2018-09-26         35063          20  1880.473684
# 1518  9.783641e+12      2018-03-05        539788         381  1425.031830
# 1519  9.788420e+12      2018-01-18        769439         958   789.254743
# 1520  9.789198e+12      2018-01-01         16558          42   377.947368
#
#                author                           title datepublished_y
# 0         Joanna Glen  The Other Half of Augusta Hope      2019-01-01  \
# 1         Joanna Glen  The Other Half of Augusta Hope      2019-01-01
# 2         Joanna Glen  The Other Half of Augusta Hope      2019-01-01
# 3         Joe Hammond      A Short History of Falling      2021-01-01
# 4      Marcie Colleen                  Love, Triangle      2017-01-01
# ...               ...                             ...             ...
# 1516  Jessica Cunsolo                   She's With Me      2020-01-01
# 1517      Amor Towles           Un gentleman à Moscou      2018-01-01
# 1518         Bas Kast           Der Ernährungskompass      2018-01-01
# 1519     Manuel Vilas                          Ordesa      2018-01-01
# 1520   Danielle Koste                           Pulse      2018-01-01
#
#              author_l  advance_id  ... Competition Awards Bestseller
# 0         joanna glen       66000  ...         YES    NaN        NaN  \
# 1         joanna glen       66000  ...         YES    NaN        NaN
# 2         joanna glen       66000  ...         YES    NaN        NaN
# 3         joe hammond       57848  ...         YES    NaN        NaN
# 4      marcie colleen      106679  ...         YES    NaN        NaN
# ...               ...         ...  ...         ...    ...        ...
# 1516  jessica cunsolo       52135  ...         NaN    NaN        NaN
# 1517      amor towles       90863  ...         NaN    NaN        NaN
# 1518         bas kast       61933  ...         YES    NaN        NaN
# 1519     manuel vilas       45720  ...         NaN    NaN        NaN
# 1520   danielle koste       92090  ...         NaN    NaN        NaN
#
#      Self Publishing Debut Series
# 0                NaN   YES    NaN  \
# 1                NaN   YES    NaN
# 2                NaN   YES    NaN
# 3                NaN   NaN    NaN
# 4                NaN   NaN    NaN
# ...              ...   ...    ...
# 1516             NaN   NaN    NaN
# 1517             NaN   NaN    NaN
# 1518             NaN   NaN    NaN
# 1519             NaN   NaN    NaN
# 1520             NaN   NaN    NaN
#
#                                                     All  Author_extracted
# 0     Joanna Glen's debut THE FLIGHT OF AUGUSTA HOPE...       joanna glen  \
# 1     Joanna Glen's debut THE FLIGHT OF AUGUSTA HOPE...       joanna glen
# 2     Joanna Glen's debut THE FLIGHT OF AUGUSTA HOPE...       joanna glen
# 3     Playwright Joe Hammond's A SHORT HISTORY OF FA...       joe hammond
# 4     Marcie Colleen's LOVE, TRIANGLE, about best fr...    marcie colleen
# ...                                                 ...               ...
# 1516  Jessica Cunsolo's SHE'S WITH ME, reported as o...   jessica cunsolo
# 1517  Rules of Civility author Amor Towles next two ...       amor towles
# 1518  Bas Kast's DER ERNAHRUNGSKOMPASS, to Business ...          bas kast
# 1519  Manuel Vilas's ORDESA, to Writers Publishing H...      manuel vilas
# 1520  Danielle Koste's PULSE, pitched as reminiscent...    danielle koste
#
#      fuzz_ratio                        title_extracted
# 0            75          THE FLIGHT OF AUGUSTA HOPE UK
# 1            75          THE FLIGHT OF AUGUSTA HOPE UK
# 2            75          THE FLIGHT OF AUGUSTA HOPE UK
# 3           100           SHORT HISTORY OF FALLING ALS
# 4           100                          LOVE TRIANGLE
# ...         ...                                    ...
# 1516        100                            SHE WITH ME
# 1517         33                                  NA UK
# 1518         98                  DER ERNAHRUNGSKOMPASS
# 1519        100                                 ORDESA
# 1520        100  PULSE LET THE RIGHT ONE IN UNDERWORLD
#
# [1449 rows x 28 columns]

# %%
fm = fm.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['datepublished_y'].idxmax()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dfefc2229cd1> in <module>
# ----> 1 fm = fm.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['datepublished_y'].idxmax()])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1351         with option_context("mode.chained_assignment", None):
#    1352             try:
# -> 1353                 result = self._python_apply_general(f, self._selected_obj)
#    1354             except TypeError:
#    1355                 # gh-20949
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1400             data after applying f
#    1401         """
# -> 1402         values, mutated = self.grouper.apply(f, data, self.axis)
#    1403         if not_indexed_same is None:
#    1404             not_indexed_same = mutated
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     765             # group might be modified
#     766             group_axes = group.axes
# --> 767             res = f(group)
#     768             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769                 mutated = True
#
# <ipython-input-80-dfefc2229cd1> in <lambda>(x)
# ----> 1 fm = fm.groupby('isbn13', as_index=False).apply(lambda x : x.loc[x['datepublished_y'].idxmax()])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2525         # error: Argument 1 to "argmax" of "IndexOpsMixin" has incompatible type
#    2526         # "Union[int, Literal['index', 'columns']]"; expected "Optional[int]"
# -> 2527         i = self.argmax(axis, skipna, *args, **kwargs)  # type: ignore[arg-type]
#    2528         if i == -1:
#    2529             return np.nan
#
# ~/.local/lib/python3.8/site-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     672                 return -1
#     673             else:
# --> 674                 return delegate.argmax()
#     675         else:
#     676             # error: Incompatible return value type (got "Union[int, ndarray]", expected
#
# ~/.local/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py in argmax(self, axis, skipna)
#     207         if not skipna and self._hasna:
#     208             raise NotImplementedError
# --> 209         return nargminmax(self, "argmax", axis=axis)
#     210
#     211     def unique(self: NDArrayBackedExtensionArrayT) -> NDArrayBackedExtensionArrayT:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/sorting.py in nargminmax(values, method, axis)
#     471         return func(arr_values, axis=axis)
#     472
# --> 473     return _nanargminmax(arr_values, mask, func)
#     474
#     475
#
# ~/.local/lib/python3.8/site-packages/pandas/core/sorting.py in _nanargminmax(values, mask, func)
#     482     non_nan_idx = idx[~mask]
#     483
# --> 484     return non_nan_idx[func(non_nans)]
#     485
#     486
#
# ~/.local/lib/python3.8/site-packages/numpy/core/overrides.py in argmax(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in argmax(a, axis, out, keepdims)
#    1214     """
#    1215     kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216     return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#    1217
#    1218
#
# ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ValueError: attempt to get argmax of an empty sequence

# %%
print(fm.shape, fm['advance_id'].unique().shape, fm['isbn13'].unique().shape, fm['author_l'].unique().shape)
# Out:
# (1449, 28) (1052,) (1052,) (979,)

# %%
x = pd.merge(d, sales,on='isbn13')
x = x.groupby('isbn13',as_index=False).apply(lambda x: x.loc[x['datepublished_y'].idxmax()])

# %%
x
# Out:
#                  author                                              title
# 0         Steven Camden                                    It’s About Love  \
# 1          Casey Watson  Runaway Girl: A beautiful girl. Trafficked for...
# 2       Dolores Redondo  Offering to the Storm (The Baztan Trilogy, Boo...
# 3        Sam Carrington                                      Saving Sophie
# 4           Katy Colins                                    Chasing the Sun
# ...                 ...                                                ...
# 3878      Anisur Rahman                            Hazaron Khawaishen Aisi
# 3879      Chris Skinner  Digital Bank: Strategies to launch or become a...
# 3880  Florencia Bonelli                         Dime, ¿quién es como Dios?
# 3881       Mackenzi Lee    La guía del caballero para el vicio y la virtud
# 3882        Clare Lydon                               Once Upon a Princess
#
#      datepublished_x         isbn13           author_l datepublished_y
# 0               2015  9780007511259      steven camden      2015-06-04  \
# 1         2016-10-20  9780008142599       casey watson      2016-10-20
# 2               2017  9780008165550    dolores redondo      2017-08-24
# 3         2016-08-12  9780008191863     sam carrington      2018-08-12
# 4         2017-07-27  9780008202200        katy colins      2017-07-27
# ...              ...            ...                ...             ...
# 3878            2018  9789353023409      anisur rahman      2018-12-25
# 3879            2014  9789814561808      chris skinner      2014-05-15
# 3880            2019  9789877391305  florencia bonelli      2019-04-12
# 3881            2015  9789877473315       mackenzi lee      2017-09-08
# 3882      2018-12-06  9789887801443        clare lydon      2018-05-22
#
#       totalrevenue  totalunits        price
# 0            60130         270   613.152174
# 1          1119609        1595   697.559242
# 2           160920         205   708.347305
# 3              299           1   299.000000
# 4            36575         125   295.153846
# ...            ...         ...          ...
# 3878         16516          27   606.246154
# 3879       1437877         899  1609.589069
# 3880          3297           3  1099.000000
# 3881          4194           6   710.111111
# 3882       4975867        9322   835.639024
#
# [3883 rows x 9 columns]

# %%
y = pd.merge(df, x, on=['author_l', 'title'])

# %%
y
# Out:
#             author_x                                              title
# 0        Malka Adler                          The Brothers of Auschwitz  \
# 1          Liana Liu                                     The Memory Key
# 2    Suzanne Crowley                                       Finding Esme
# 3     Claire Needell                               The First True Thing
# 4         Roxane Gay                                       Not That Bad
# ..               ...                                                ...
# 560      Brian Banks  What Set Me Free (The Story That Inspired the ...
# 561     Leslie Nagel                               The Codebook Murders
# 562        Joel Dane                                         Kill Orbit
# 563      Amor Towles                              Un gentleman à Moscou
# 564      Joan Silber                                        Improvement
#
#     datepublished       isbn13_x         author_l  advance_id
# 0      2019-01-01  9780008386115      malka adler       34526  \
# 1      2015-01-01  9780062306661        liana liu      124290
# 2      2018-01-01  9780062352484  suzanne crowley      117324
# 3      2019-01-01  9780062360540   claire needell       62980
# 4      2018-01-01  9780062413505       roxane gay       39661
# ..            ...            ...              ...         ...
# 560    2019-01-01  9781982121327      brian banks       60101
# 561    2019-01-01  9781984800268     leslie nagel       95236
# 562    2020-01-01  9781984802576        joel dane       65841
# 563    2018-01-01  9782213704296      amor towles       90863
# 564    2021-01-01  9787559400727      joan silber       64662
#
#           Rights Category                 Genre       Date        Author(s)
# 0    International rights               Fiction 2020-10-12             NONE  \
# 1              Children's   Young Adult Fiction 2013-03-26        Liana Liu
# 2              Children's  Middle Grade Fiction 2013-11-22  Suzanne Crowley
# 3              Children's   Young Adult Fiction 2018-07-06   Claire Needell
# 4    International rights           Non-fiction 2020-05-15             NONE
# ..                    ...                   ...        ...              ...
# 560           Non-fiction        General/ Other 2018-09-29      Brian Banks
# 561       Digital Fiction        Mystery/ Crime 2015-12-02     Leslie Nagel
# 562               Fiction       Sci-Fi/ Fantasy 2018-04-12        Joel Dane
# 563               Fiction        General/ Other 2016-04-13      Amor Towles
# 564  International rights               Fiction 2018-05-15             NONE
#
#      ... Author_extracted fuzz_ratio                        title_extracted
# 0    ...      malka adler        100           THE BROTHERS OF AUSCHWITZ UK  \
# 1    ...        liana liu        100                  MFA THE MEMORY KEY NA
# 2    ...  suzanne crowley        100                           FINDING ESME
# 3    ...   claire needell        100  THE WORD FOR YES THE FIRST TRUE THING
# 4    ...       roxane gay        100                           NOT THAT BAD
# ..   ...              ...        ...                                    ...
# 560  ...      brian banks         43          NFL THE BRIAN BANKS STORY NFL
# 561  ...     leslie nagel         78               THE BOOK CLUB MURDERS UK
# 562  ...        joel dane         49     CRY PILOT BURN CYCLE KILL ORBIT SF
# 563  ...      amor towles         33                                  NA UK
# 564  ...      joan silber         79                      IMPROVEMENT FOOLS
#
#             author_y datepublished_x       isbn13_y datepublished_y
# 0        Malka Adler            2019  9780008386115      2019-11-07  \
# 1          Liana Liu            2015  9780062306661      2015-03-03
# 2    Suzanne Crowley            2018  9780062352484      2018-08-14
# 3     Claire Needell            2019  9780062360540      2019-04-23
# 4         Roxane Gay            2018  9780062413505      2023-11-06
# ..               ...             ...            ...             ...
# 560      Brian Banks            2019  9781982121327      2019-07-02
# 561     Leslie Nagel            2019  9781984800268      2019-05-21
# 562        Joel Dane            2020  9781984802576      2020-07-07
# 563      Amor Towles            2018  9782213704296      2018-09-26
# 564      Joan Silber            2017  9781619029712      2017-11-01
#
#     totalrevenue totalunits        price
# 0        1470355      11475   229.008850
# 1           7182         18   403.333333
# 2          18535         23   800.656250
# 3          11487         13   887.317003
# 4              0          0   853.000000
# ..           ...        ...          ...
# 560       526512        409  1277.327645
# 561      1103078       3355   491.674944
# 562        69537         81   889.858586
# 563        35063         20  1880.473684
# 564     12126261      12840   910.965937
#
# [565 rows x 31 columns]

# %%
y.columns
# Out:
# Index(['author_x', 'title_x', 'datepublished', 'isbn13_x', 'author_l',
#        'advance_id', 'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title',
#        'Publishers', 'Big Publishing House Affilation', 'Advance',
#        'Competition', 'Awards', 'Bestseller', 'Self Publishing', 'Debut',
#        'Series', 'All', 'Author_extracted', 'fuzz_ratio', 'title_extracted',
#        'author_y', 'title_y', 'datepublished_x', 'isbn13_y', 'datepublished_y',
#        'totalrevenue', 'totalunits', 'price'],
#       dtype='object')

# %%
y['fuzz_ratio_1'] = book_adv.apply(lambda x : levenshtein_ratio(str(x['title_']).lower(), str(x['title']).lower()), axis=1)
# Out:
#                     author_x                                        title_x
# 0              Steven Camden                                           Tape  \
# 1     Alexander McCall Smith                                           Emma
# 2     Alexander McCall Smith                                           Emma
# 3     Alexander McCall Smith                              Corduroy Mansions
# 4     Alexander McCall Smith                              Corduroy Mansions
# ...                      ...                                            ...
# 4185           Troy Cummings  Troy Cummings's the Binder of Doom Collection
# 4186             Aisha Saeed                              Le Courage d'Amal
# 4187           Jaime Lorente                    Basho and the Pattern 5-7-5
# 4188            Olivia Miles                              A Promise to Keep
# 4189            Olivia Miles                               A Wish Come True
#
#      datepublished       isbn13_x                author_l  advance_id
# 0       2014-01-01  9780007511211           steven camden      118703  \
# 1       2015-01-01  9780007553884  alexander mccall smith      118748
# 2       2015-01-01  9780007553884  alexander mccall smith      118748
# 3              NaT  9780307398345  alexander mccall smith      150523
# 4              NaT  9780307398345  alexander mccall smith      150523
# ...            ...            ...                     ...         ...
# 4185    2022-01-01  9789813383531           troy cummings       20827
# 4186    2021-01-01  9791023514698             aisha saeed       53030
# 4187    2023-01-01  9798376140987           jaime lorente       26465
# 4188    2023-01-01  9798986262451            olivia miles       11138
# 4189    2023-01-01  9798986262468            olivia miles       21315
#
#            Rights Category                 Genre       Date
# 0     International rights            UK Fiction 2013-10-08  \
# 1                  Fiction        General/ Other 2013-10-07
# 2                  Fiction        General/ Other 2013-10-07
# 3                  Fiction        General/ Other 2010-05-25
# 4                  Fiction        General/ Other 2010-05-25
# ...                    ...                   ...        ...
# 4185            Children's  Picture Book Fiction 2021-09-28
# 4186            Children's   Young Adult Fiction 2019-04-17
# 4187  International rights               Fiction 2021-05-04
# 4188          Audio rights                  NONE 2022-05-20
# 4189          Audio rights                  NONE 2021-09-16
#
#                                 Author(s)  ... fuzz_ratio
# 0                           Steven Camden  ...        100  \
# 1                  Alexander McCall Smith  ...        100
# 2                  Alexander McCall Smith  ...        100
# 3                                    NONE  ...        100
# 4                                    NONE  ...        100
# ...                                   ...  ...        ...
# 4185                        Troy Cummings  ...         35
# 4186  ['Becky Albertalli', 'Aisha Saeed']  ...         44
# 4187                                 NONE  ...         33
# 4188                         Olivia Miles  ...         33
# 4189                         Olivia Miles  ...         43
#
#                                        title_extracted
# 0                                              TAPE UK  \
# 1                                                 EMMA
# 2                                                 EMMA
# 3                    CORDUROY MANSIONS SCOTLAND STREET
# 4                    CORDUROY MANSIONS SCOTLAND STREET
# ...                                                ...
# 4185             NYT CAN BE YOUR DOG OTTO THE ORNAMENT
# 4186                               NYT YES NO MAYBE SO
# 4187                                  ABOUT YOUR MOUTH
# 4188  PLACE FOR US SECOND CHANCE SUMMER BECAUSE OF YOU
# 4189                      MEET ME AT SUNSET SUMMER END
#
#                     author_y
# 0              Steven Camden  \
# 1     Alexander McCall Smith
# 2     Alexander McCall Smith
# 3     Alexander McCall Smith
# 4     Alexander McCall Smith
# ...                      ...
# 4185           Troy Cummings
# 4186             Aisha Saeed
# 4187           Jaime Lorente
# 4188            Olivia Miles
# 4189            Olivia Miles
#
#                                                 title_y datepublished_x
# 0                                       It’s About Love            2015  \
# 1                             The Sands of Shark Island      2017-07-11
# 2                                           Dream Angus            2012
# 3                             The Sands of Shark Island      2017-07-11
# 4                                           Dream Angus            2012
# ...                                                 ...             ...
# 4185  Boa Constructor: A Branches Book (The Binder o...            2019
# 4186                          Aladdin: Far From Agrabah            2019
# 4187                             A propósito de tu boca            2019
# 4188                            The Winter Wedding Plan            2017
# 4189                            The Winter Wedding Plan            2017
#
#            isbn13_y datepublished_y totalrevenue totalunits        price
# 0     9780007511259      2015-06-04        60130        270   613.152174
# 1     9780399554032      2017-07-11        82523         78  1066.443719
# 2     9780802194220      2019-04-24       119274        426   457.742222
# 3     9780399554032      2017-07-11        82523         78  1066.443719
# 4     9780802194220      2019-04-24       119274        426   457.742222
# ...             ...             ...          ...        ...          ...
# 4185  9781338314717      2019-09-03        89545        363   249.735043
# 4186  9781368047425      2019-09-03         1099          1  1099.000000
# 4187  9788467055542      2019-03-19        26071         29   856.190476
# 4188  9781455567249      2017-09-26      2889301       4421   639.829344
# 4189  9781455567249      2017-09-26      2889301       4421   639.829344
#
# [4190 rows x 32 columns]

# %% [markdown]
# ## Ethnicity Prediction of Author

# %%
from ethnicolr import pred_fl_reg_name

# %%
def preprocess_names(df, Column_Name):
    #Remove space if the first letter of the word is a space
    df['temp_Column_Name'] = df[Column_Name]
    df['temp_Column_Name'] = df['temp_Column_Name'].str.lstrip()
    
    #Remove single letter in the Names
    #df[Column_Name] = df[Column_Name].str.replace(r'\b[A-Za-z]\b', '')
    df['temp_Column_Name'] = df['temp_Column_Name'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 1]))
    #Remove names in brackets
    #df[Column_Name] = df[Column_Name].str.replace(r'\s?\([^()]*\)', '')
    df['temp_Column_Name'] = df['temp_Column_Name'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))
    
    rwords = ['Doctor','Professor','Captain','Jr','Sr','III','II', 'IV']
    for word in rwords:
        df.loc[:, 'temp_Column_Name'] = df['temp_Column_Name'].str.replace(word,"")
        
    df['temp_Column_Name'] = df['temp_Column_Name'].str.lstrip()
    
    df['First Name'] = df['temp_Column_Name'].str.split(" ", expand=True)[0]
    df['Last Name'] = df['temp_Column_Name'].str.split().str[-1]
    df.drop(columns=['temp_Column_Name'], inplace=True)
    return df

# %%
fm
# Out:
#            isbn13 datepublished_x  totalrevenue  totalunits        price
# 0    9.780008e+12      2020-03-05         25201          20  1309.250000  \
# 1    9.780008e+12      2021-04-06          1899           1  1680.235294
# 2    9.780062e+12      2017-10-03       1252305        1127  1048.526147
# 3    9.780062e+12      2019-06-25         10188           6  1698.000000
# 4    9.780063e+12      2018-07-24       1492131        1364  1070.016355
# ..            ...             ...           ...         ...          ...
# 590  9.798501e+12      2021-05-08          1399           1  1399.000000
# 591  9.798617e+12      2020-02-25         19481          19  1023.444444
# 592  9.798642e+12      2020-04-30        487017         351  1390.812834
# 593  9.798682e+12      2020-09-03       1926121        1223  1593.222222
# 594  9.798696e+12      2020-10-09          4097           3  1444.454545
#
#                    author                                    title
# 0             Joanna Glen           The Other Half of Augusta Hope  \
# 1             Joe Hammond               A Short History of Falling
# 2          Marcie Colleen                           Love, Triangle
# 3            Alissa Quart                                 Squeezed
# 4             Erin Bowman                                Contagion
# ..                    ...                                      ...
# 590        Aj Vanderhorst  The Mostly Invisible Boy (Casey Grimes)
# 591  Christopher Ruocchio                         The Lesser Devil
# 592         Shannon Mayer                    Midlife Bounty Hunter
# 593         Carrie Aarons                      Love at First Fight
# 594         Scott Dikkers         The Joke at the End of the World
#
#     datepublished_y              author_l  advance_id  ... Competition Awards
# 0        2019-01-01           joanna glen       66000  ...         YES    NaN  \
# 1        2021-01-01           joe hammond       57848  ...         YES    NaN
# 2        2017-01-01        marcie colleen      106679  ...         YES    NaN
# 3        2019-01-01          alissa quart       60539  ...         YES    NaN
# 4        2018-01-01           erin bowman       82642  ...         NaN    NaN
# ..              ...                   ...         ...  ...         ...    ...
# 590      2021-01-01        aj vanderhorst       46214  ...         NaN    NaN
# 591      2020-01-01  christopher ruocchio       93513  ...         NaN    NaN
# 592             NaT         shannon mayer       35513  ...         NaN    NaN
# 593             NaT         carrie aarons       24416  ...         NaN    NaN
# 594      2020-01-01         scott dikkers       91199  ...         NaN    NaN
#
#     Bestseller Self Publishing Debut Series
# 0          NaN             NaN   YES    NaN  \
# 1          NaN             NaN   NaN    NaN
# 2          NaN             NaN   NaN    NaN
# 3          NaN             NaN   NaN    NaN
# 4          NaN             NaN   NaN    YES
# ..         ...             ...   ...    ...
# 590        NaN             NaN   YES    NaN
# 591        NaN             NaN   NaN    NaN
# 592        NaN             NaN   NaN    NaN
# 593        NaN             NaN   NaN    NaN
# 594        NaN             NaN   NaN    NaN
#
#                                                    All      Author_extracted
# 0    Joanna Glen's debut THE FLIGHT OF AUGUSTA HOPE...           joanna glen  \
# 1    Playwright Joe Hammond's A SHORT HISTORY OF FA...           joe hammond
# 2    Marcie Colleen's LOVE, TRIANGLE, about best fr...        marcie colleen
# 3    Alissa Quart's SQUEEZED, to Gusa (Taiwan, Prov...          alissa quart
# 4    VENGEANCE ROAD author Erin Bowman's sci-fi CON...           erin bowman
# ..                                                 ...                   ...
# 590  AJ Vanderhorst's debut THE MOSTLY INVISIBLE BO...        aj vanderhorst
# 591  Christopher Ruocchio's THE MURDERED SUM, Book ...  christopher ruocchio
# 592  Shannon Mayer's MIDLIFE BOUNTY HUNTER, to Eksm...         shannon mayer
# 593  Carrie Aarons's LOVE AT FIRST FIGHT, to Tantor...         carrie aarons
# 594  French rights to Scott Dikkers's TRUMP'S AMERI...         scott dikkers
#
#     fuzz_ratio                         title_extracted
# 0           75           THE FLIGHT OF AUGUSTA HOPE UK
# 1          100            SHORT HISTORY OF FALLING ALS
# 2          100                           LOVE TRIANGLE
# 3          100                                SQUEEZED
# 4          100             VENGEANCE ROAD CONTAGION NA
# ..         ...                                     ...
# 590         79          AJ THE MOSTLY INVISIBLE BOY US
# 591         50              THE MURDERED SUM DAW NA UK
# 592        100                   MIDLIFE BOUNTY HUNTER
# 593        100                     LOVE AT FIRST FIGHT
# 594         43  TRUMP AMERICA THE COMPLETE LOSER GUIDE
#
# [595 rows x 28 columns]

# %%
dg = preprocess_names(fm, 'author_l')

# %%
dg1 = dg.copy()

# %%
eth = pred_fl_reg_name(dg,'Last Name', 'First Name')

# %%
x = dg1.merge(eth, on=['First Name', 'Last Name'], how='outer')

# %%
x.columns
# Out:
# Index(['isbn13_x', 'datepublished_x_x', 'totalrevenue_x', 'totalunits_x',
#        'price_x', 'author_x', 'title_x', 'datepublished_y_x', 'author_l_x',
#        'advance_id_x', 'Rights Category_x', 'Genre_x', 'Date_x', 'Author(s)_x',
#        'Title_x', 'Publishers_x', 'Big Publishing House Affilation_x',
#        'Advance_x', 'Competition_x', 'Awards_x', 'Bestseller_x',
#        'Self Publishing_x', 'Debut_x', 'Series_x', 'All_x',
#        'Author_extracted_x', 'fuzz_ratio_x', 'title_extracted_x', 'First Name',
#        'Last Name', 'isbn13_y', 'datepublished_x_y', 'totalrevenue_y',
#        'totalunits_y', 'price_y', 'author_y', 'title_y', 'datepublished_y_y',
#        'author_l_y', 'advance_id_y', 'Rights Category_y', 'Genre_y', 'Date_y',
#        'Author(s)_y', 'Title_y', 'Publishers_y',
#        'Big Publishing House Affilation_y', 'Advance_y', 'Competition_y',
#        'Awards_y', 'Bestseller_y', 'Self Publishing_y', 'Debut_y', 'Series_y',
#        'All_y', 'Author_extracted_y', 'fuzz_ratio_y', 'title_extracted_y',
#        'asian', 'hispanic', 'nh_black', 'nh_white', 'race'],
#       dtype='object')

# %%
x = x[[column for column in x.columns if not column.endswith('_y')]]

# %%
x.columns  = x.columns.str.replace('_x','')

# %%
x.columns
# Out:
# Index(['isbn13', 'datepublished', 'totalrevenue', 'totalunits', 'price',
#        'author', 'title', 'datepublished_y', 'author_l', 'advance_id',
#        'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All',
#        'Author_extracted', 'fuzz_ratio', 'title_extracted', 'First Name',
#        'Last Name', 'asian', 'hispanic', 'nh_black', 'nh_white', 'race'],
#       dtype='object')

# %%
x = x.rename(columns={
    
})

# %%
x.to_csv('SGAADV_ebook.csv')

# %%
x.columns
# Out:
# Index(['isbn13', 'datepublished', 'totalrevenue', 'totalunits', 'price',
#        'author', 'title', 'datepublished_y', 'author_l', 'advance_id',
#        'Rights Category', 'Genre', 'Date', 'Author(s)', 'Title', 'Publishers',
#        'Big Publishing House Affilation', 'Advance', 'Competition', 'Awards',
#        'Bestseller', 'Self Publishing', 'Debut', 'Series', 'All',
#        'Author_extracted', 'fuzz_ratio', 'title_extracted', 'First Name',
#        'Last Name', 'asian', 'hispanic', 'nh_black', 'nh_white', 'race'],
#       dtype='object')

# %%
x['datepublished_month'] = x['datepublished'].dt.strftime('%Y-%m')

# %%
x.groupby('datepublished_month')[['totalrevenue', 'Advance','isbn13']].sum().to_csv('printbook_datewise.csv')
